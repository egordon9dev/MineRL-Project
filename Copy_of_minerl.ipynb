# %% [markdown]
# ## Install Minerl

# %%
# !pip3 install --upgrade minerl
# Out:
# Collecting minerl
#   Downloading https://files.pythonhosted.org/packages/ca/a2/3fab937b6019a19470bd2864cf20ce9f9a3a5d54fb7894a4b96cd54db039/minerl-0.3.6.tar.gz (36.3MB)
#      |████████████████████████████████| 36.3MB 83kB/s
# Requirement already satisfied, skipping upgrade: gym>=0.13.1 in /usr/local/lib/python3.6/dist-packages (from minerl) (0.17.3)
# Requirement already satisfied, skipping upgrade: opencv-python>=4.1.0.25 in /usr/local/lib/python3.6/dist-packages (from minerl) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: setuptools>=40.6.2 in /usr/local/lib/python3.6/dist-packages (from minerl) (50.3.2)
# Requirement already satisfied, skipping upgrade: tqdm>=4.32.2 in /usr/local/lib/python3.6/dist-packages (from minerl) (4.41.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.2 in /usr/local/lib/python3.6/dist-packages (from minerl) (1.18.5)
# Requirement already satisfied, skipping upgrade: requests>=2.20.0 in /usr/local/lib/python3.6/dist-packages (from minerl) (2.23.0)
# Collecting ipython>=7.5.0
#   Downloading https://files.pythonhosted.org/packages/23/6a/210816c943c9aeeb29e4e18a298f14bf0e118fe222a23e13bfcc2d41b0a4/ipython-7.16.1-py3-none-any.whl (785kB)
#      |████████████████████████████████| 788kB 34.4MB/s
# Collecting typing>=3.6.6
#   Downloading https://files.pythonhosted.org/packages/05/d9/6eebe19d46bd05360c9a9aae822e67a80f9242aabbfc58b641b957546607/typing-3.7.4.3.tar.gz (78kB)
#      |████████████████████████████████| 81kB 8.6MB/s
# Collecting lxml>=4.3.3
#   Downloading https://files.pythonhosted.org/packages/64/28/0b761b64ecbd63d272ed0e7a6ae6e4402fc37886b59181bfdf274424d693/lxml-4.6.1-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 38.1MB/s
# Collecting psutil>=5.6.2
#   Downloading https://files.pythonhosted.org/packages/33/e0/82d459af36bda999f82c7ea86c67610591cf5556168f48fd6509e5fa154d/psutil-5.7.3.tar.gz (465kB)
#      |████████████████████████████████| 471kB 42.7MB/s
# Collecting Pyro4>=4.76
#   Downloading https://files.pythonhosted.org/packages/c3/3c/422f6f761076c5679215178a00eca9a68aacfbbc88152c85b15928b60e25/Pyro4-4.80-py2.py3-none-any.whl (89kB)
#      |████████████████████████████████| 92kB 12.6MB/s
# Collecting coloredlogs>=10.0
#   Downloading https://files.pythonhosted.org/packages/5c/2f/12747be360d6dea432e7b5dfae3419132cb008535cfe614af73b9ce2643b/coloredlogs-14.0-py2.py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 8.5MB/s
# Collecting matplotlib==3.0.3
#   Downloading https://files.pythonhosted.org/packages/e9/69/f5e05f578585ed9935247be3788b374f90701296a70c8871bcd6d21edb00/matplotlib-3.0.3-cp36-cp36m-manylinux1_x86_64.whl (13.0MB)
#      |████████████████████████████████| 13.0MB 243kB/s
# Requirement already satisfied, skipping upgrade: dill>=0.3.1.1 in /usr/local/lib/python3.6/dist-packages (from minerl) (0.3.3)
# Collecting getch>=1.0
#   Downloading https://files.pythonhosted.org/packages/cc/a4/c696c05e0ff9d05b1886cb0210101083db7d330ff964a6d7cd98ad2b2064/getch-1.0.tar.gz
# Requirement already satisfied, skipping upgrade: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym>=0.13.1->minerl) (1.3.0)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from gym>=0.13.1->minerl) (1.4.1)
# Requirement already satisfied, skipping upgrade: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym>=0.13.1->minerl) (1.5.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->minerl) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->minerl) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->minerl) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->minerl) (2020.6.20)
# Requirement already satisfied, skipping upgrade: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=7.5.0->minerl) (0.7.5)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=7.5.0->minerl) (4.8.0)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/8a/aa/198e6a857e83ea8b711a6ae0c37717c0eb1b23ff52e3732a644fcd389cb3/prompt_toolkit-3.0.8-py3-none-any.whl (355kB)
#      |████████████████████████████████| 358kB 47.3MB/s
# Requirement already satisfied, skipping upgrade: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython>=7.5.0->minerl) (4.3.3)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in /usr/local/lib/python3.6/dist-packages (from ipython>=7.5.0->minerl) (0.17.2)
# Requirement already satisfied, skipping upgrade: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=7.5.0->minerl) (2.6.1)
# Requirement already satisfied, skipping upgrade: decorator in /usr/local/lib/python3.6/dist-packages (from ipython>=7.5.0->minerl) (4.4.2)
# Requirement already satisfied, skipping upgrade: backcall in /usr/local/lib/python3.6/dist-packages (from ipython>=7.5.0->minerl) (0.2.0)
# Collecting serpent>=1.27; python_version >= "3.2"
#   Downloading https://files.pythonhosted.org/packages/b4/a1/24871492bfc34ea18aee3bf38e0cee22d8c11d8d5e765ccc921103140747/serpent-1.30.2-py3-none-any.whl
# Collecting humanfriendly>=7.1
#   Downloading https://files.pythonhosted.org/packages/8e/2d/2f1b0a780b8c948c06c74c8c80e68ac354da52397ba432a1c5ac1923c3af/humanfriendly-8.2-py2.py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 12.2MB/s
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib==3.0.3->minerl) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib==3.0.3->minerl) (1.3.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib==3.0.3->minerl) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib==3.0.3->minerl) (2.8.1)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym>=0.13.1->minerl) (0.16.0)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=7.5.0->minerl) (0.6.0)
# Requirement already satisfied, skipping upgrade: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.5.0->minerl) (0.2.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython>=7.5.0->minerl) (1.15.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython>=7.5.0->minerl) (0.2.0)
# Requirement already satisfied, skipping upgrade: parso<0.8.0,>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from jedi>=0.10->ipython>=7.5.0->minerl) (0.7.1)
# Building wheels for collected packages: minerl, typing, psutil, getch
#   Building wheel for minerl (setup.py) ... done
#   Created wheel for minerl: filename=minerl-0.3.6-cp36-none-any.whl size=72040787 sha256=2b2666c2d9d58eb07d660f329e1042407694396f3c9cdefe74921a4ff6839ea8
#   Stored in directory: /root/.cache/pip/wheels/8e/dc/c9/a7f3c17ccc05df396620a9e6921936d3bd35df1f25466c9fd7
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-cp36-none-any.whl size=26307 sha256=9a39819eaa45917f31c6c7c4e23b63053a1b4847e09fe75d844319d2f960cccd
#   Stored in directory: /root/.cache/pip/wheels/2d/04/41/8e1836e79581989c22eebac3f4e70aaac9af07b0908da173be
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.7.3-cp36-cp36m-linux_x86_64.whl size=281528 sha256=e9ebeef42a25bd06c79e5a100616f9bf5bc3df148c260744db259dff0a88f68a
#   Stored in directory: /root/.cache/pip/wheels/42/32/da/8b12fd6b138c733efd03cfde6c6c8191a32842f9e82aa45fbf
#   Building wheel for getch (setup.py) ... done
#   Created wheel for getch: filename=getch-1.0-cp36-cp36m-linux_x86_64.whl size=14215 sha256=153097602af7431503313486e094c5dfed97c0831b76902c24398d6e9c75fe56
#   Stored in directory: /root/.cache/pip/wheels/82/9d/22/6d295c77d3b78954fe41dd47464e605e8b82802071005169c5
# Successfully built minerl typing psutil getch
# ERROR: plotnine 0.6.0 has requirement matplotlib>=3.1.1, but you'll have matplotlib 3.0.3 which is incompatible.
# ERROR: mizani 0.6.0 has requirement matplotlib>=3.1.1, but you'll have matplotlib 3.0.3 which is incompatible.
# ERROR: jupyter-console 5.2.0 has requirement prompt-toolkit<2.0.0,>=1.0.0, but you'll have prompt-toolkit 3.0.8 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement ipython~=5.5.0, but you'll have ipython 7.16.1 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: prompt-toolkit, ipython, typing, lxml, psutil, serpent, Pyro4, humanfriendly, coloredlogs, matplotlib, getch, minerl
#   Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
#   Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# Successfully installed Pyro4-4.80 coloredlogs-14.0 getch-1.0 humanfriendly-8.2 ipython-7.16.1 lxml-4.6.1 matplotlib-3.0.3 minerl-0.3.6 prompt-toolkit-3.0.8 psutil-5.7.3 serpent-1.30.2 typing-3.7.4.3

# %% [markdown]
# ## Install Java

# %%
import os       #importing os to set environment variable
def install_java():
    # !sudo add-apt-repository ppa:openjdk-r/ppa
    # !sudo apt-get update
    # !sudo apt-get install openjdk-8-jdk
    os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"     #set environment variable
    # !java -version       #check java version

# %%
install_java()
# Out:
#
#  More info: https://launchpad.net/~openjdk-r/+archive/ubuntu/ppa
# Press [ENTER] to continue or Ctrl-c to cancel adding it.
#
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Ign:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [407 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:15 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [58.5 kB]
# Get:16 http://ppa.launchpad.net/openjdk-r/ppa/ubuntu bionic InRelease [15.4 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [222 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,198 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,688 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [15.8 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,781 kB]
# Get:22 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,365 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [46.3 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,129 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [247 kB]
# Get:26 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [864 kB]
# Get:27 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [46.6 kB]
# Get:28 http://ppa.launchpad.net/openjdk-r/ppa/ubuntu bionic/main amd64 Packages [10.6 kB]
# Fetched 11.4 MB in 2s (4,661 kB/s)
# Reading package lists... Done
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/openjdk-r/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libxxf86dga1 openjdk-8-jdk-headless openjdk-8-jre
#   openjdk-8-jre-headless x11-utils
# Suggested packages:
#   gvfs openjdk-8-demo openjdk-8-source visualvm icedtea-8-plugin libnss-mdns
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libxxf86dga1 openjdk-8-jdk openjdk-8-jdk-headless
#   openjdk-8-jre openjdk-8-jre-headless x11-utils
# 0 upgraded, 15 newly installed, 0 to remove and 40 not upgraded.
# Need to get 43.4 MB of archives.
# After this operation, 163 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java all 0.33.3-20ubuntu0.1 [34.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java-jni amd64 0.33.3-20ubuntu0.1 [28.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre-headless amd64 8u275-b01-0ubuntu1~18.04 [28.2 MB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre amd64 8u275-b01-0ubuntu1~18.04 [69.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk-headless amd64 8u275-b01-0ubuntu1~18.04 [8,269 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk amd64 8u275-b01-0ubuntu1~18.04 [1,600 kB]
# Fetched 43.4 MB in 2s (23.7 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 15.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 144786 files and directories currently installed.)
# Preparing to unpack .../00-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../01-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../02-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../03-x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../04-libatk-wrapper-java_0.33.3-20ubuntu0.1_all.deb ...
# Unpacking libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../05-libatk-wrapper-java-jni_0.33.3-20ubuntu0.1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../06-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../07-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../08-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../09-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../10-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# Preparing to unpack .../11-openjdk-8-jre-headless_8u275-b01-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u275-b01-0ubuntu1~18.04) ...
# Selecting previously unselected package openjdk-8-jre:amd64.
# Preparing to unpack .../12-openjdk-8-jre_8u275-b01-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jre:amd64 (8u275-b01-0ubuntu1~18.04) ...
# Selecting previously unselected package openjdk-8-jdk-headless:amd64.
# Preparing to unpack .../13-openjdk-8-jdk-headless_8u275-b01-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk-headless:amd64 (8u275-b01-0ubuntu1~18.04) ...
# Selecting previously unselected package openjdk-8-jdk:amd64.
# Preparing to unpack .../14-openjdk-8-jdk_8u275-b01-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk:amd64 (8u275-b01-0ubuntu1~18.04) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Setting up openjdk-8-jre-headless:amd64 (8u275-b01-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up openjdk-8-jdk-headless:amd64 (8u275-b01-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/idlj to provide /usr/bin/idlj (idlj) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsimport to provide /usr/bin/wsimport (wsimport) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jsadebugd to provide /usr/bin/jsadebugd (jsadebugd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/native2ascii to provide /usr/bin/native2ascii (native2ascii) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/javah to provide /usr/bin/javah (javah) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/clhsdb to provide /usr/bin/clhsdb (clhsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/xjc to provide /usr/bin/xjc (xjc) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/hsdb to provide /usr/bin/hsdb (hsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/schemagen to provide /usr/bin/schemagen (schemagen) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/extcheck to provide /usr/bin/extcheck (extcheck) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jhat to provide /usr/bin/jhat (jhat) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsgen to provide /usr/bin/wsgen (wsgen) in auto mode
# Setting up x11-utils (7.7+3build1) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Setting up openjdk-8-jre:amd64 (8u275-b01-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/policytool to provide /usr/bin/policytool (policytool) in auto mode
# Setting up openjdk-8-jdk:amd64 (8u275-b01-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/appletviewer to provide /usr/bin/appletviewer (appletviewer) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# openjdk version "11.0.9" 2020-10-20
# OpenJDK Runtime Environment (build 11.0.9+11-Ubuntu-0ubuntu1.18.04.1)
# OpenJDK 64-Bit Server VM (build 11.0.9+11-Ubuntu-0ubuntu1.18.04.1, mixed mode)

# %% [markdown]
# ## Install NoVNC to display environment

# %%
# NoVNC
! wget https://raw.githubusercontent.com/blacktanktop/minerl_colab/master/install_novnc.sh    
! bash install_novnc.sh

import os
os.environ['PATH'] += "/opt/TurboVNC/bin"
! mkdir -p /content/.vnc

# Ngrok
! wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
! unzip -d /opt ngrok-stable-linux-amd64.zip 
! rm ngrok-stable-linux-amd64.zip 
! echo "web_addr: 4045" > /content/config.yml
# Out:
# --2020-11-13 14:45:44--  https://raw.githubusercontent.com/blacktanktop/minerl_colab/master/install_novnc.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1685 (1.6K) [text/plain]
# Saving to: ‘install_novnc.sh’
#
# install_novnc.sh    100%[===================>]   1.65K  --.-KB/s    in 0s
#
# 2020-11-13 14:45:44 (32.6 MB/s) - ‘install_novnc.sh’ saved [1685/1685]
#
# Selecting previously unselected package libjpeg-turbo-official.
# (Reading database ... 145362 files and directories currently installed.)
# Preparing to unpack libjpeg-turbo-official_1.5.2_amd64.deb ...
# Unpacking libjpeg-turbo-official (1.5.2-20170707) ...
# Selecting previously unselected package turbovnc.
# Preparing to unpack turbovnc_2.1.2_amd64.deb ...
# Unpacking turbovnc (2.1.2-20170925) ...
# Setting up libjpeg-turbo-official (1.5.2-20170707) ...
# Setting up turbovnc (2.1.2-20170925) ...
# Processing triggers for systemd (237-3ubuntu10.42) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# cc -fPIC   -c -o rebind.o rebind.c
# cc  rebind.o -shared -fPIC -ldl -o rebind.so
# Hit:1 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/openjdk-r/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# --2020-11-13 14:46:18--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 34.205.238.171, 18.213.76.145, 54.236.132.162, ...
# Connecting to bin.equinox.io (bin.equinox.io)|34.205.238.171|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  45.9MB/s    in 0.3s
#
# 2020-11-13 14:46:18 (45.9 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: /opt/ngrok

# %%
# !kill $(ps ax | grep websockify | grep -v grep | awk '{ print $1 }') >/dev/null
# !pkill ngrok
# !pkill vncserver
# !pkill Xvnc
# !pkill Xvfb
# !pkill x11vnc
# Out:
# kill: usage: kill [-s sigspec | -n signum | -sigspec] pid | jobspec ... or kill -l [sigspec]

# %%
# !timeout 5 /opt/websockify/run 5901 --web=/opt/noVNC --wrap-mode=ignore -- /opt/TurboVNC/bin/vncserver :1 -securitytypes otp -otp -noxstartup 2>/dev/null
get_ipython().system_raw('python /opt/websockify/run 5901 --web=/opt/noVNC --wrap-mode=ignore -- /opt/TurboVNC/bin/vncserver :1 -securitytypes otp -otp -noxstartup > /content/.vnc/stdout 2>&1 &')
get_ipython().system_raw('/opt/ngrok http -config=/content/config.yml 5901 &')
# !sleep 1
get_ipython().system_raw('DISPLAY=:1 openbox &')

# %%
# !grep "one-time password:" /content/.vnc/stdout

import requests
import json
r = requests.get("http://localhost:4045/api/tunnels", headers={"content-type": "application/json"})
print(r.json()['tunnels'][0]['public_url'])
# Out:
# Full control one-time password: 26347041
# http://f1de66d3d969.ngrok.io

# %%
get_ipython().system_raw('/usr/bin/Xvfb :99 -screen 0 768x1024x24 &')
# !sleep 1
get_ipython().system_raw('/usr/bin/x11vnc -rfbport 5902 -forever -display :99 &')
# !sleep 1
get_ipython().system_raw('DISPLAY=:1 /usr/bin/vncviewer localhost:5902 &')
# !sleep 1
get_ipython().system_raw('DISPLAY=:99 xterm &')

# %% [markdown]
# ## No Action Test

# %%
# %env DISPLAY=:99

import minerl
import gym
import logging
logging.basicConfig(level=logging.DEBUG)
env = gym.make('MineRLNavigateDense-v0')


obs  = env.reset()
done = False
net_reward = 0
while not done:
    action = env.action_space.noop()

    action['camera'] = [0, 0.03*obs["compassAngle"]]
    action['back'] = 0
    action['forward'] = 1
    action['jump'] = 1
    action['attack'] = 1

    obs, reward, done, info = env.step(action)

    net_reward += reward
    print("Total reward: ", net_reward)
# Out:
# INFO:minerl.env.malmo.instance.4e2a81:Starting Minecraft process: ['/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/launchClient.sh', '-port', '12604', '-env', '-runDir', '/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/run']
# INFO:minerl.env.malmo.instance.4e2a81:Starting process watcher for process 41418 @ localhost:12604
# env: DISPLAY=:99
# DEBUG:minerl.env.malmo.instance.4e2a81:This mapping 'snapshot_20161220' was designed for MC 1.11! Use at your own peril.
# DEBUG:minerl.env.malmo.instance.4e2a81:#################################################
# DEBUG:minerl.env.malmo.instance.4e2a81:         ForgeGradle 2.2-SNAPSHOT-3966cea
# DEBUG:minerl.env.malmo.instance.4e2a81:  https://github.com/MinecraftForge/ForgeGradle
# DEBUG:minerl.env.malmo.instance.4e2a81:#################################################
# DEBUG:minerl.env.malmo.instance.4e2a81:               Powered by MCP unknown
# DEBUG:minerl.env.malmo.instance.4e2a81:             http://modcoderpack.com
# DEBUG:minerl.env.malmo.instance.4e2a81:         by: Searge, ProfMobius, Fesh0r,
# DEBUG:minerl.env.malmo.instance.4e2a81:         R4wk, ZeuX, IngisKahn, bspkrs
# DEBUG:minerl.env.malmo.instance.4e2a81:#################################################
# DEBUG:minerl.env.malmo.instance.4e2a81:Found AccessTransformer: malmomod_at.cfg
# DEBUG:minerl.env.malmo.instance.4e2a81::deobfCompileDummyTask
# DEBUG:minerl.env.malmo.instance.4e2a81::deobfProvidedDummyTask
# DEBUG:minerl.env.malmo.instance.4e2a81::getVersionJson
# DEBUG:minerl.env.malmo.instance.4e2a81::extractUserdev
# DEBUG:minerl.env.malmo.instance.4e2a81::downloadClient SKIPPED
# DEBUG:minerl.env.malmo.instance.4e2a81::downloadServer SKIPPED
# DEBUG:minerl.env.malmo.instance.4e2a81::splitServerJar SKIPPED
# DEBUG:minerl.env.malmo.instance.4e2a81::mergeJars SKIPPED
# DEBUG:minerl.env.malmo.instance.4e2a81::applyBinaryPatches
# DEBUG:minerl.env.malmo.instance.4e2a81::extractDependencyATs SKIPPED
# DEBUG:minerl.env.malmo.instance.4e2a81::extractMcpData SKIPPED
# DEBUG:minerl.env.malmo.instance.4e2a81::extractMcpMappings SKIPPED
# DEBUG:minerl.env.malmo.instance.4e2a81::genSrgs SKIPPED
# DEBUG:minerl.env.malmo.instance.4e2a81::deobfMcMCP
# DEBUG:minerl.env.malmo.instance.4e2a81:Applying SpecialSource...
# DEBUG:minerl.env.malmo.instance.4e2a81:Applying Exceptor...
# DEBUG:minerl.env.malmo.instance.4e2a81:Applying RuntimeInvisibleParameterAnnotations workaround...
# DEBUG:minerl.env.malmo.instance.4e2a81::sourceApiJava
# DEBUG:minerl.env.malmo.instance.4e2a81::compileApiJava UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.4e2a81::processApiResources UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.4e2a81::apiClasses UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.4e2a81::copyModToClient UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.4e2a81::copyModToServer UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.4e2a81::copySrg
# DEBUG:minerl.env.malmo.instance.4e2a81::deleteSchemas
# DEBUG:minerl.env.malmo.instance.4e2a81::copySchemas
# DEBUG:minerl.env.malmo.instance.4e2a81::jaxb
# DEBUG:minerl.env.malmo.instance.4e2a81::sourceMainJava
# DEBUG:minerl.env.malmo.instance.4e2a81::compileJavawarning: [options] bootstrap class path not set in conjunction with -source 1.6
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: SpongePowered MIXIN Annotation Processor Version=0.7.5
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: ObfuscationServiceMCP supports type: "searge"
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: ObfuscationServiceMCP supports type: "notch"
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Loading searge mappings from /Users/maxrudolph/.gradle/caches/minecraft/de/oceanlabs/mcp/mcp_snapshot/20161220/1.11.2/srgs/mcp-srg.srg
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Loading notch mappings from /Users/maxrudolph/.gradle/caches/minecraft/de/oceanlabs/mcp/mcp_snapshot/20161220/1.11.2/srgs/mcp-notch.srg
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Writing refmap to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/tmp/compileJava/compileJava-refmap.json
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Writing refmap to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/tmp/compileJava/compileJava-refmap.json
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Writing searge output SRGs to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/tmp/compileJava/mcp-srg.srg
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Writing notch output SRGs to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/tmp/compileJava/mcp-notch.srg
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Writing refmap to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/tmp/compileJava/compileJava-refmap.json
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Writing refmap to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/tmp/compileJava/compileJava-refmap.json
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Writing searge output SRGs to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/tmp/compileJava/mcp-srg.srg
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Writing notch output SRGs to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/tmp/compileJava/mcp-notch.srg
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Some input files use or override a deprecated API.
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Recompile with -Xlint:deprecation for details.
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Some input files use unchecked or unsafe operations.
# DEBUG:minerl.env.malmo.instance.4e2a81:Note: Recompile with -Xlint:unchecked for details.
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81::processResources
# DEBUG:minerl.env.malmo.instance.4e2a81::classes
# DEBUG:minerl.env.malmo.instance.4e2a81::jar
# DEBUG:minerl.env.malmo.instance.4e2a81::extractNatives SKIPPED
# DEBUG:minerl.env.malmo.instance.4e2a81::getAssetIndex UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.4e2a81::getAssets
# DEBUG:minerl.env.malmo.instance.4e2a81::makeStart SKIPPED
# DEBUG:minerl.env.malmo.instance.4e2a81::runClient
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Extra: []
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Found and added coremod: com.microsoft.Malmo.OverclockingPlugin
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Running with arguments: [--userProperties, {}, --assetsDir, /Users/maxrudolph/.gradle/caches/minecraft/assets, --assetIndex, 1.11, --accessToken{REDACTED}, --version, 1.11.2, --tweakClass, net.minecraftforge.fml.common.launcher.FMLTweaker, --tweakClass, net.minecraftforge.gradle.tweakers.CoremodTweaker]
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Loading tweak class name net.minecraftforge.fml.common.launcher.FMLTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Using primary tweak class name net.minecraftforge.fml.common.launcher.FMLTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Loading tweak class name net.minecraftforge.gradle.tweakers.CoremodTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Calling tweak class net.minecraftforge.fml.common.launcher.FMLTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Forge Mod Loader version 13.20.0.2228 for Minecraft 1.11.2 loading
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Java is OpenJDK 64-Bit Server VM, version 1.8.0_272, running on Mac OS X:x86_64:10.15.7, installed at /Library/Java/JavaVirtualMachines/adoptopenjdk-8.jdk/Contents/Home/jre
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Managed to load a deobfuscated Minecraft name- we are in a deobfuscated environment. Skipping runtime deobfuscation
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Found a command line coremod : com.microsoft.Malmo.OverclockingPlugin
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/WARN]: The coremod com.microsoft.Malmo.OverclockingPlugin does not have a MCVersion annotation, it may cause issues with this version of Minecraft
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: SpongePowered MIXIN Subsystem Version=0.7.5 Source=file:/Users/maxrudolph/.gradle/caches/modules-2/files-2.1/org.spongepowered/mixin/0.7.5-SNAPSHOT/c989878008c2c5ff1a7c6491c4103d8faa221d19/mixin-0.7.5-SNAPSHOT.jar Service=LaunchWrapper Env=CLIENT
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Compatibility level set to JAVA_8
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Calling tweak class net.minecraftforge.gradle.tweakers.CoremodTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Injecting location in coremod net.minecraftforge.fml.relauncher.FMLCorePlugin
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Injecting location in coremod net.minecraftforge.classloading.FMLForgePlugin
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Injecting location in coremod com.microsoft.Malmo.OverclockingPlugin
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Loading tweak class name net.minecraftforge.fml.common.launcher.FMLInjectionAndSortingTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Loading tweak class name org.spongepowered.asm.mixin.EnvironmentStateTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Loading tweak class name net.minecraftforge.fml.common.launcher.FMLDeobfTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Loading tweak class name net.minecraftforge.gradle.tweakers.AccessTransformerTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Calling tweak class net.minecraftforge.fml.common.launcher.FMLInjectionAndSortingTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Calling tweak class net.minecraftforge.fml.common.launcher.FMLInjectionAndSortingTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Calling tweak class net.minecraftforge.fml.relauncher.CoreModManager$FMLPluginWrapper
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/ERROR]: The binary patch set is missing. Either you are in a development environment, or things are not going to work!
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/ERROR]: FML appears to be missing any signature data. This is not a good thing
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Calling tweak class net.minecraftforge.fml.relauncher.CoreModManager$FMLPluginWrapper
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Calling tweak class net.minecraftforge.fml.relauncher.CoreModManager$FMLPluginWrapper
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Calling tweak class org.spongepowered.asm.mixin.EnvironmentStateTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Initialised Mixin FML Remapper Adapter with net.minecraftforge.fml.common.asm.transformers.deobf.FMLDeobfuscatingRemapper@75201592
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:07] [main/INFO]: Calling tweak class net.minecraftforge.fml.common.launcher.FMLDeobfTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: Calling tweak class net.minecraftforge.gradle.tweakers.AccessTransformerTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: Loading tweak class name net.minecraftforge.fml.common.launcher.TerminalTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: Calling tweak class net.minecraftforge.fml.common.launcher.TerminalTweaker
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/WARN]: Reference map 'mixins.replaymod.refmap.json' for mixins.overclocking.malmomod.json could not be read. If this is a development environment you can ignore this message
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:transform:58]: MALMO: Attempting to transform MinecraftServer
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:129]: MALMO: Found Minecraft, attempting to transform it
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:135]: MALMO: Found Minecraft.runGameLoop() method, attempting to transform it
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:150]: MALMO: Hooked into call to Minecraft.updateDisplay()
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: A re-entrant transformer '$wrapper.com.microsoft.Malmo.OverclockingClassTransformer' was detected and will no longer process meta class data
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: Launching wrapped minecraft {net.minecraft.client.main.Main}
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:transform:58]: MALMO: Attempting to transform MinecraftServer
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:129]: MALMO: Found Minecraft, attempting to transform it
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:135]: MALMO: Found Minecraft.runGameLoop() method, attempting to transform it
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:150]: MALMO: Hooked into call to Minecraft.updateDisplay()
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:transform:42]: Transformed Name: net.minecraft.client.entity.EntityPlayerSP
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:08] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:transform:42]: Transformed Name: net.minecraft.client.entity.AbstractClientPlayer
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:09] [Client thread/INFO]: Setting user: Player265
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:12] [Client thread/WARN]: Skipping bad option: lastServer:
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:12] [Client thread/INFO]: LWJGL Version: 2.9.2
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:12] [Client thread/INFO]: [STDOUT]: MALMO: Attempting to transform MinecraftServer
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:12] [Client thread/INFO]: [STDOUT]: MALMO: Found GlStateManager, attempting to transform it
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:12] [Client thread/INFO]: [STDOUT]: MALMO: Found GlStateManager.bindTexture() method, attempting to transform it
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:12] [Client thread/INFO]: [STDOUT]: MALMO: Hooked into call to GlStateManager.bindTexture()
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:12] [Client thread/INFO]: MinecraftForge v13.20.0.2228 Initialized
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:12] [Client thread/INFO]: Replaced 232 ore recipes
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:12] [Client thread/INFO]: Found 0 mods from the command line. Injecting into mod discoverer
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:12] [Client thread/INFO]: Searching /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/run/mods for mods
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Forge Mod Loader has identified 5 mods to load
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Attempting connection with missing mods [minecraft, mcp, FML, forge, malmomod] at CLIENT
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Attempting connection with missing mods [minecraft, mcp, FML, forge, malmomod] at SERVER
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Reloading ResourceManager: Default, FMLFileResourcePack:Forge Mod Loader, FMLFileResourcePack:Minecraft Forge, FMLFileResourcePack:Microsoft Malmo Mod
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Processing ObjectHolder annotations
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Found 444 ObjectHolder annotations
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Identifying ItemStackHolder annotations
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Found 0 ItemStackHolder annotations
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Applying holder lookups
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Holder lookups applied
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Applying holder lookups
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Holder lookups applied
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Applying holder lookups
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Holder lookups applied
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Configured a dormant chunk cache size of 0
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Forge Version Check/INFO]: [forge] Starting version check at http://files.minecraftforge.net/maven/net/minecraftforge/forge/promotions_slim.json
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: [STDOUT]: Testing schemas against internal version number: 0.37
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Forge Version Check/INFO]: [forge] Found status: OUTDATED Target: 13.20.1.2386
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: [STDOUT]: [LOGTOPY] Performance directory not specified.
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: [STDOUT]: [ERROR] Seed specified was NONE. Expected a long (integer).
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Applying holder lookups
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Holder lookups applied
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Injecting itemstacks
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:14] [Client thread/INFO]: Itemstack injection complete
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:15] [Sound Library Loader/INFO]: Starting up SoundSystem...
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:16] [Thread-5/INFO]: Initializing LWJGL OpenAL
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:16] [Thread-5/INFO]: (The LWJGL binding of OpenAL.  For more information, see http://www.lwjgl.org)
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:16] [Thread-5/INFO]: OpenAL initialized.
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:16] [Sound Library Loader/INFO]: Sound engine started
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:17] [Client thread/INFO]: Max texture size: 16384
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:17] [Client thread/INFO]: Created: 16x16 textures-atlas
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:18] [Client thread/INFO]: [STDOUT]: CLIENT request state: WAITING_FOR_MOD_READY
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:18] [Client thread/INFO]: Injecting itemstacks
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:18] [Client thread/INFO]: Itemstack injection complete
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:18] [Client thread/INFO]: Forge Mod Loader has successfully loaded 5 mods
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:18] [Client thread/INFO]: Reloading ResourceManager: Default, FMLFileResourcePack:Forge Mod Loader, FMLFileResourcePack:Minecraft Forge, FMLFileResourcePack:Microsoft Malmo Mod
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:18] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:18] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:18] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmps_r4ea8v/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:19] [Client thread/INFO]: SoundSystem shutting down...
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:19] [Client thread/WARN]: Author: Paul Lamb, www.paulscode.com
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:19] [Sound Library Loader/INFO]: Starting up SoundSystem...
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:19] [Thread-7/INFO]: Initializing LWJGL OpenAL
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:19] [Thread-7/INFO]: (The LWJGL binding of OpenAL.  For more information, see http://www.lwjgl.org)
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:19] [Thread-7/INFO]: OpenAL initialized.
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:19] [Sound Library Loader/INFO]: Sound engine started
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:20] [Client thread/INFO]: Max texture size: 16384
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:20] [Client thread/INFO]: Created: 512x512 textures-atlas
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:21] [Client thread/WARN]: Skipping bad option: lastServer:
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:21] [Client thread/INFO]: [STDOUT]: CLIENT enter state: WAITING_FOR_MOD_READY
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:21] [Client thread/INFO]: [STDOUT]: ***** Start MalmoEnvServer on port 12604
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:21] [Client thread/INFO]: [STDOUT]: CLIENT request state: DORMANT
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:21] [Client thread/INFO]: [STDOUT]: CLIENT enter state: DORMANT
# INFO:minerl.env.malmo.instance.4e2a81:Minecraft process ready
# INFO:minerl.env.malmo:Logging output of Minecraft to ./logs/mc_3604.log
# DEBUG:minerl.env.core:Creating socket connection!
# DEBUG:minerl.env.core:Sending mission init!
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:21] [EnvServerSocketHandler/INFO]: [STDOUT]: Received from localhost:<MissionInit xmlns="http://ProjectMalmo.microsoft.com" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" SchemaVersion="" PlatformVersion="0.37.0">
# DEBUG:minerl.env.malmo.instance.4e2a81:                                <Mission>
# DEBUG:minerl.env.malmo.instance.4e2a81:    <About>
# DEBUG:minerl.env.malmo.instance.4e2a81:        <Summary>MineRLNavigateDense-v0</Summary>
# DEBUG:minerl.env.malmo.instance.4e2a81:    </About>
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:    <ModSettings>
# DEBUG:minerl.env.malmo.instance.4e2a81:        <MsPerTick>50</MsPerTick>
# DEBUG:minerl.env.malmo.instance.4e2a81:    </ModSettings>
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:    <ServerSection>
# DEBUG:minerl.env.malmo.instance.4e2a81:        <ServerInitialConditions>
# DEBUG:minerl.env.malmo.instance.4e2a81:            <Time>
# DEBUG:minerl.env.malmo.instance.4e2a81:                <StartTime>6000</StartTime>
# DEBUG:minerl.env.malmo.instance.4e2a81:                <AllowPassageOfTime>false</AllowPassageOfTime>
# DEBUG:minerl.env.malmo.instance.4e2a81:            </Time>
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:            <Weather>clear</Weather>
# DEBUG:minerl.env.malmo.instance.4e2a81:            <AllowSpawning>false</AllowSpawning>
# DEBUG:minerl.env.malmo.instance.4e2a81:        </ServerInitialConditions>
# DEBUG:minerl.env.malmo.instance.4e2a81:        <ServerHandlers>
# DEBUG:minerl.env.malmo.instance.4e2a81:            <DefaultWorldGenerator forceReset="true"/>
# DEBUG:minerl.env.malmo.instance.4e2a81:            <NavigationDecorator>
# DEBUG:minerl.env.malmo.instance.4e2a81:                <randomPlacementProperties>
# DEBUG:minerl.env.malmo.instance.4e2a81:                    <maxRandomizedRadius>64</maxRandomizedRadius>
# DEBUG:minerl.env.malmo.instance.4e2a81:                    <minRandomizedRadius>64</minRandomizedRadius>
# DEBUG:minerl.env.malmo.instance.4e2a81:                    <maxRadius>8</maxRadius>
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [Realms Notification Availability checker #1/INFO]: Could not authorize you against Realms server: Invalid session id
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [EnvServerSocketHandler/INFO]: [STDOUT]: REPLYING WITH: MALMOOK
# DEBUG:minerl.env.core:Peeking the client.
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [Client thread/INFO]: [STDOUT]: Mission received: MineRLNavigateDense-v0
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [Client thread/INFO]: [STDOUT]: CLIENT request state: CREATING_HANDLERS
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [Client thread/INFO]: [STDOUT]: CLIENT enter state: CREATING_HANDLERS
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [Client thread/INFO]: [STDOUT]: Starting command server.
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [Thread-10/INFO]: [STDOUT]: INFO: ->com(0) Listening for messages on port 10984
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [Client thread/INFO]: [STDOUT]: CLIENT request state: EVALUATING_WORLD_REQUIREMENTS
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [Client thread/INFO]: [STDOUT]: CLIENT enter state: EVALUATING_WORLD_REQUIREMENTS
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [Client thread/INFO]: [STDOUT]: CLIENT request state: CREATING_NEW_WORLD
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:22] [Client thread/INFO]: [STDOUT]: CLIENT enter state: CREATING_NEW_WORLD
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:23] [Server thread/INFO]: Starting integrated minecraft server version 1.11.2
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:23] [Server thread/INFO]: Generating keypair
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:23] [Server thread/INFO]: Injecting existing block and item data into this server instance
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:23] [Server thread/INFO]: Applying holder lookups
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:23] [Server thread/INFO]: Holder lookups applied
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:23] [Server thread/INFO]: Loading dimension 0 (TEMP_0_e0bf1306-f819-422a-af1c-f0b0ad313d8f) (net.minecraft.server.integrated.IntegratedServer@479ec43)
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:23] [Server thread/WARN]: Unable to find spawn biome
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:24] [Server thread/INFO]: Loading dimension 1 (TEMP_0_e0bf1306-f819-422a-af1c-f0b0ad313d8f) (net.minecraft.server.integrated.IntegratedServer@479ec43)
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:24] [Server thread/INFO]: Loading dimension -1 (TEMP_0_e0bf1306-f819-422a-af1c-f0b0ad313d8f) (net.minecraft.server.integrated.IntegratedServer@479ec43)
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:24] [Server thread/INFO]: Preparing start region for level 0
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:25] [Server thread/INFO]: Preparing spawn area: 16%
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:26] [Server thread/INFO]: Preparing spawn area: 34%
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:27] [Server thread/INFO]: Preparing spawn area: 50%
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:28] [Server thread/INFO]: Preparing spawn area: 65%
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:29] [Server thread/INFO]: Preparing spawn area: 83%
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: Preparing spawn area: 99%
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: Changing view distance to 4, from 10
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Netty Local Client IO #0/INFO]: [STDOUT]: Transformed Name: net.minecraft.client.entity.EntityOtherPlayerMP
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Netty Local Client IO #0/INFO]: [STDOUT]: MALMO: Attempting to transform MinecraftServer
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Netty Local Client IO #0/INFO]: [STDOUT]: MALMO: Found EntityOtherPlayerMP, attempting to transform it
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [STDOUT]: SERVER request state: WAITING_FOR_MOD_READY
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [STDOUT]: CLIENT request state: WAITING_FOR_SERVER_READY
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [STDOUT]: SERVER enter state: WAITING_FOR_MOD_READY
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Client thread/INFO]: [STDOUT]: CLIENT enter state: WAITING_FOR_SERVER_READY
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [STDOUT]: SERVER request state: DORMANT
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [STDOUT]: SERVER enter state: DORMANT
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Netty Local Client IO #0/INFO]: Server protocol version 2
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [STDOUT]: INCOMING MISSION: Received MissionInit directly through ServerStateMachine constructor.
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [STDOUT]: Mission received: MineRLNavigateDense-v0
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Netty Server IO #1/INFO]: Client protocol version 2
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: Received mission: §9MineRLNavigateDense-v0
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: Source: §alocalhost
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [STDOUT]: SERVER request state: BUILDING_WORLD
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [STDOUT]: SERVER enter state: BUILDING_WORLD
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Netty Server IO #1/INFO]: Client attempting to join with 5 mods : minecraft@1.11.2,FML@8.0.99.99,malmomod@0.37.0,forge@13.20.0.2228,mcp@9.19
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [STDOUT]: SERVER request state: WAITING_FOR_AGENTS_TO_ASSEMBLE
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Netty Local Client IO #0/INFO]: [Netty Local Client IO #0] Client side modded connection established
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: [Server thread] Server side modded connection established
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:30] [Server thread/INFO]: MineRLAgent[local:E:7555ee47] logged in with entity id 1714 at (0.5, 64.0, 1.5)
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:31] [Server thread/INFO]: MineRLAgent joined the game
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:31] [Server thread/INFO]: [STDOUT]: SERVER enter state: WAITING_FOR_AGENTS_TO_ASSEMBLE
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:31] [Server thread/INFO]: [STDOUT]: Experiment requires:
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:31] [Server thread/INFO]: [STDOUT]: >>>> MineRLAgent
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:32] [Client thread/INFO]: [STDOUT]: ***Telling server we are ready - MineRLAgent
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:32] [Client thread/INFO]: [STDOUT]: ***Telling server we are ready - MineRLAgent
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:32] [Client thread/INFO]: [STDOUT]: CLIENT request state: RUNNING
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:32] [Client thread/INFO]: [STDOUT]: CLIENT enter state: RUNNING
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:32] [Server thread/INFO]: [STDOUT]: SERVER request state: RUNNING
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:32] [Server thread/INFO]: [STDOUT]: SERVER enter state: RUNNING
# DEBUG:minerl.env.malmo.instance.4e2a81:[13:27:32] [Client thread/INFO]: [STDOUT]: Resized the window
# DEBUG:minerl.env.malmo.instance.4e2a81:2020-11-14 13:27:32.314 java[41433:5636957] *** Terminating app due to uncaught exception 'NSInternalInconsistencyException', reason: 'NSWindow drag regions should only be invalidated on the Main Thread!'
# DEBUG:minerl.env.malmo.instance.4e2a81:*** First throw call stack:
# DEBUG:minerl.env.comms:Pause before retry on 'NoneType' object has no attribute 'decode'
# DEBUG:minerl.env.malmo.instance.4e2a81:(
# DEBUG:minerl.env.malmo.instance.4e2a81:	0   CoreFoundation                      0x00007fff32964b57 __exceptionPreprocess + 250
# DEBUG:minerl.env.malmo.instance.4e2a81:	1   libobjc.A.dylib                     0x00007fff6b7b05bf objc_exception_throw + 48
# DEBUG:minerl.env.malmo.instance.4e2a81:	2   CoreFoundation                      0x00007fff3298d34c -[NSException raise] + 9
# DEBUG:minerl.env.malmo.instance.4e2a81:	3   AppKit                              0x00007fff2fb875ec -[NSWindow(NSWindow_Theme) _postWindowNeedsToResetDragMarginsUnlessPostingDisabled] + 310
# DEBUG:minerl.env.malmo.instance.4e2a81:	4   AppKit                              0x00007fff2fbb1cee -[NSThemeFrame setStyleMask:] + 137
# DEBUG:minerl.env.malmo.instance.4e2a81:	5   AppKit                              0x00007fff2fbb1b3c __25-[NSWindow setStyleMask:]_block_invoke + 1908
# DEBUG:minerl.env.malmo.instance.4e2a81:	6   AppKit                              0x00007fff2fbb136e NSPerformVisuallyAtomicChange + 132
# DEBUG:minerl.env.malmo.instance.4e2a81:	7   AppKit                              0x00007fff2fbb1279 -[NSWindow setStyleMask:] + 184
# DEBUG:minerl.env.malmo.instance.4e2a81:	8   liblwjgl.dylib                      0x0000000120016ee2 Java_org_lwjgl_opengl_MacOSXDisplay_nSetResizable + 82
# DEBUG:minerl.env.malmo.instance.4e2a81:	9   ???                                 0x000000010b64c407 0x0 + 4486120455
# DEBUG:minerl.env.malmo.instance.4e2a81:)
# DEBUG:minerl.env.malmo.instance.4e2a81:libc++abi.dylib: terminating with uncaught exception of type NSException
# DEBUG:minerl.env.malmo.instance.4e2a81::runClient FAILED
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:FAILURE: Build failed with an exception.
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:* What went wrong:
# DEBUG:minerl.env.malmo.instance.4e2a81:Execution failed for task ':runClient'.
# DEBUG:minerl.env.malmo.instance.4e2a81:> Process 'command '/Library/Java/JavaVirtualMachines/adoptopenjdk-8.jdk/Contents/Home/bin/java'' finished with non-zero exit value 134
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:* Try:
# DEBUG:minerl.env.malmo.instance.4e2a81:Run with --info or --debug option to get more log output.
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:* Exception is:
# DEBUG:minerl.env.malmo.instance.4e2a81:org.gradle.api.tasks.TaskExecutionException: Execution failed for task ':runClient'.
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.executeActions(ExecuteActionsTaskExecuter.java:69)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.execute(ExecuteActionsTaskExecuter.java:46)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.PostExecutionAnalysisTaskExecuter.execute(PostExecutionAnalysisTaskExecuter.java:35)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.SkipUpToDateTaskExecuter.execute(SkipUpToDateTaskExecuter.java:66)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.ValidatingTaskExecuter.execute(ValidatingTaskExecuter.java:58)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.SkipEmptySourceFilesTaskExecuter.execute(SkipEmptySourceFilesTaskExecuter.java:52)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.SkipTaskWithNoActionsExecuter.execute(SkipTaskWithNoActionsExecuter.java:52)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.SkipOnlyIfTaskExecuter.execute(SkipOnlyIfTaskExecuter.java:53)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.ExecuteAtMostOnceTaskExecuter.execute(ExecuteAtMostOnceTaskExecuter.java:43)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.taskgraph.DefaultTaskGraphExecuter$EventFiringTaskWorker.execute(DefaultTaskGraphExecuter.java:203)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.taskgraph.DefaultTaskGraphExecuter$EventFiringTaskWorker.execute(DefaultTaskGraphExecuter.java:185)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.taskgraph.AbstractTaskPlanExecutor$TaskExecutorWorker.processTask(AbstractTaskPlanExecutor.java:66)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.taskgraph.AbstractTaskPlanExecutor$TaskExecutorWorker.run(AbstractTaskPlanExecutor.java:50)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.taskgraph.DefaultTaskPlanExecutor.process(DefaultTaskPlanExecutor.java:25)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.taskgraph.DefaultTaskGraphExecuter.execute(DefaultTaskGraphExecuter.java:110)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.SelectedTaskExecutionAction.execute(SelectedTaskExecutionAction.java:37)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.DefaultBuildExecuter.execute(DefaultBuildExecuter.java:37)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.DefaultBuildExecuter.access$000(DefaultBuildExecuter.java:23)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.DefaultBuildExecuter$1.proceed(DefaultBuildExecuter.java:43)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.DryRunBuildExecutionAction.execute(DryRunBuildExecutionAction.java:32)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.DefaultBuildExecuter.execute(DefaultBuildExecuter.java:37)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.execution.DefaultBuildExecuter.execute(DefaultBuildExecuter.java:30)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.initialization.DefaultGradleLauncher$4.run(DefaultGradleLauncher.java:153)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.internal.Factories$1.create(Factories.java:22)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:91)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:53)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.initialization.DefaultGradleLauncher.doBuildStages(DefaultGradleLauncher.java:150)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.initialization.DefaultGradleLauncher.access$200(DefaultGradleLauncher.java:32)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.initialization.DefaultGradleLauncher$1.create(DefaultGradleLauncher.java:98)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.initialization.DefaultGradleLauncher$1.create(DefaultGradleLauncher.java:92)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:91)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:63)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.initialization.DefaultGradleLauncher.doBuild(DefaultGradleLauncher.java:92)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.initialization.DefaultGradleLauncher.run(DefaultGradleLauncher.java:83)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.exec.InProcessBuildActionExecuter$DefaultBuildController.run(InProcessBuildActionExecuter.java:99)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.tooling.internal.provider.ExecuteBuildActionRunner.run(ExecuteBuildActionRunner.java:28)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.exec.ChainingBuildActionRunner.run(ChainingBuildActionRunner.java:35)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.exec.InProcessBuildActionExecuter.execute(InProcessBuildActionExecuter.java:48)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.exec.InProcessBuildActionExecuter.execute(InProcessBuildActionExecuter.java:30)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.exec.ContinuousBuildActionExecuter.execute(ContinuousBuildActionExecuter.java:81)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.exec.ContinuousBuildActionExecuter.execute(ContinuousBuildActionExecuter.java:46)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.exec.DaemonUsageSuggestingBuildActionExecuter.execute(DaemonUsageSuggestingBuildActionExecuter.java:51)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.exec.DaemonUsageSuggestingBuildActionExecuter.execute(DaemonUsageSuggestingBuildActionExecuter.java:28)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.cli.RunBuildAction.run(RunBuildAction.java:43)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.internal.Actions$RunnableActionAdapter.execute(Actions.java:173)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.cli.CommandLineActionFactory$ParseAndBuildAction.execute(CommandLineActionFactory.java:239)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.cli.CommandLineActionFactory$ParseAndBuildAction.execute(CommandLineActionFactory.java:212)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.cli.JavaRuntimeValidationAction.execute(JavaRuntimeValidationAction.java:35)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.cli.JavaRuntimeValidationAction.execute(JavaRuntimeValidationAction.java:24)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.cli.ExceptionReportingAction.execute(ExceptionReportingAction.java:33)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.cli.ExceptionReportingAction.execute(ExceptionReportingAction.java:22)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.cli.CommandLineActionFactory$WithLogging.execute(CommandLineActionFactory.java:205)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.cli.CommandLineActionFactory$WithLogging.execute(CommandLineActionFactory.java:169)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.Main.doAction(Main.java:33)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.bootstrap.EntryPoint.run(EntryPoint.java:45)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.bootstrap.ProcessBootstrap.runNoExit(ProcessBootstrap.java:55)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.bootstrap.ProcessBootstrap.run(ProcessBootstrap.java:36)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.launcher.GradleMain.main(GradleMain.java:23)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.wrapper.BootstrapMainStarter.start(BootstrapMainStarter.java:30)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.wrapper.WrapperExecutor.execute(WrapperExecutor.java:127)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.wrapper.GradleWrapperMain.main(GradleWrapperMain.java:61)
# DEBUG:minerl.env.malmo.instance.4e2a81:Caused by: org.gradle.process.internal.ExecException: Process 'command '/Library/Java/JavaVirtualMachines/adoptopenjdk-8.jdk/Contents/Home/bin/java'' finished with non-zero exit value 134
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.process.internal.DefaultExecHandle$ExecResultImpl.assertNormalExitValue(DefaultExecHandle.java:367)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.process.internal.DefaultJavaExecAction.execute(DefaultJavaExecAction.java:31)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.tasks.JavaExec.exec(JavaExec.java:74)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.internal.reflect.JavaMethod.invoke(JavaMethod.java:75)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.project.taskfactory.AnnotationProcessingTaskFactory$StandardTaskAction.doExecute(AnnotationProcessingTaskFactory.java:228)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.project.taskfactory.AnnotationProcessingTaskFactory$StandardTaskAction.execute(AnnotationProcessingTaskFactory.java:221)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.project.taskfactory.AnnotationProcessingTaskFactory$StandardTaskAction.execute(AnnotationProcessingTaskFactory.java:210)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.AbstractTask$TaskActionWrapper.execute(AbstractTask.java:621)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.AbstractTask$TaskActionWrapper.execute(AbstractTask.java:604)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.executeAction(ExecuteActionsTaskExecuter.java:80)
# DEBUG:minerl.env.malmo.instance.4e2a81:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.executeActions(ExecuteActionsTaskExecuter.java:61)
# DEBUG:minerl.env.malmo.instance.4e2a81:	... 60 more
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:BUILD FAILED
# DEBUG:minerl.env.malmo.instance.4e2a81:
# DEBUG:minerl.env.malmo.instance.4e2a81:Total time: 51.626 secs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/minerl/env/comms.py in wrapper(*args, **kwargs)
#      38             try:
# ---> 39                 return func(*args, **kwargs)
#      40             except Pyro4.errors.PyroError as e:
#
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/minerl/env/core.py in _start_up(self)
#     509             self.done = False
# --> 510             return self._peek_obs()
#     511         except (socket.timeout, socket.error) as e:
#
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/minerl/env/core.py in _peek_obs(self)
#     552             obs = comms.recv_message(self.client_socket)
# --> 553             info = comms.recv_message(self.client_socket).decode('utf-8')
#     554
#
# AttributeError: 'NoneType' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0b86c90d8f4d> in <module>
#       8
#       9
# ---> 10 obs  = env.reset()
#      11 done = False
#      12 net_reward = 0
#
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/gym/wrappers/time_limit.py in reset(self, **kwargs)
#      23     def reset(self, **kwargs):
#      24         self._elapsed_steps = 0
# ---> 25         return self.env.reset(**kwargs)
#
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/minerl/env/core.py in reset(self)
#     485                     time.sleep(0.1)
#     486
# --> 487             return self._start_up()
#     488         finally:
#     489             # We don't force the same seed every episode, you gotta send it yourself queen.
#
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/minerl/env/comms.py in wrapper(*args, **kwargs)
#      47                     logger.debug("Pause before retry on " + str(e))
#      48                     # raise e
# ---> 49                     time.sleep(retry_timeout)
#      50                     logger.debug("Pause complete.")
#      51         raise retry_exc
#
# KeyboardInterrupt:

# %% [markdown]
# #DQN

# %%
import gym
import math
import minerl
import random
import logging
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()
# Out:
# DEBUG:matplotlib:$HOME=/Users/maxrudolph
# DEBUG:matplotlib:CONFIGDIR=/Users/maxrudolph/.matplotlib
# DEBUG:matplotlib:matplotlib data path: /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:loaded rc file /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc
# DEBUG:matplotlib:matplotlib version 3.0.3
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is darwin
# DEBUG:matplotlib:loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'posix', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'site', 'os', 'stat', '_stat', '_collections_abc', 'posixpath', 'genericpath', 'os.path', '_sitebuiltins', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'functools', '_functools', 'mpl_toolkits', 'runpy', 'pkgutil', 'weakref', '_weakrefset', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'errno', '_posixsubprocess', 'select', 'selectors', 'collections.abc', 'math', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'logging', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'pwd', 'grp', 'traitlets', 'traitlets.traitlets', 'ast', '_ast', 'inspect', 'dis', 'opcode', '_opcode', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.utils.decorators', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'pprint', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'gettext', 'locale', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.path', 'random', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'platform', 'ipython_genutils.text', 'textwrap', 'IPython.core.crashhandler', 'IPython.core.ultratb', 'pydoc', 'sysconfig', 'urllib', 'urllib.parse', '_sysconfigdata_m_darwin_darwin', '_osx_support', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_posix', 'pexpect', 'pexpect.exceptions', 'pexpect.utils', 'pexpect.expect', 'pexpect.pty_spawn', 'pty', 'tty', 'termios', 'ptyprocess', 'ptyprocess.ptyprocess', 'fcntl', 'resource', 'struct', '_struct', 'ptyprocess.util', 'pexpect.spawnbase', 'pexpect.run', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'ntpath', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'typing', 'typing.io', 'typing.re', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.util', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments ...
# DEBUG:matplotlib:CACHEDIR=/Users/maxrudolph/.matplotlib
# DEBUG:matplotlib.font_manager:Using fontManager instance from /Users/maxrudolph/.matplotlib/fontlist-v300.json
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):

    def __init__(self, h, w, outputs):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=5, stride=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=2)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=2)
        self.bn3 = nn.BatchNorm2d(32)

        # Number of Linear input connections depends on output of conv2d layers
        # and therefore the input image size, so compute it.
        def conv2d_size_out(size, kernel_size = 5, stride = 2):
            return (size - (kernel_size - 1) - 1) // stride  + 1
        convw = conv2d_size_out(conv2d_size_out(conv2d_size_out(w)))
        convh = conv2d_size_out(conv2d_size_out(conv2d_size_out(h)))
        linear_input_size = convw * convh * 32
        self.head = nn.Linear(linear_input_size, outputs)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        return self.head(x.view(x.size(0), -1))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %env DISPLAY=:99
logging.basicConfig(level=logging.DEBUG)
env = gym.make('MineRLNavigateDense-v0')


BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10

# Get screen size so that we can initialize layers correctly based on shape
# returned from AI gym. Typical dimensions at this point are close to 3x40x90
# which is the result of a clamped and down-scaled render buffer in get_screen()
obs  = env.reset()

H,W,C = obs['pov'].shape

n_actions = 3

policy_net = DQN(H, W, n_actions).to(device)
target_net = DQN(H, W, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.RMSprop(policy_net.parameters())
memory = ReplayMemory(10000)

steps_done = 0

def converter(observation):
    region_size = 8
    obs = observation['pov']
    obs = obs / 25
    H,W,C = obs.shape
    state = torch.from_numpy(obs).float().to(device)
    if len(state.shape) < 4:
            state = torch.unsqueeze(state, 0)
    state = state.reshape((-1,C,H,W))
    return state

def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    action = env.action_space.noop()
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            action_index = policy_net(state).max(1)[1].view(1, 1)
    else:
        action_index=torch.tensor([[random.randrange(n_actions)]], device=device, dtype=torch.long)
    if (action_index == 0):
      action['camera'] = [0, -5]
    elif (action_index == 1):
      action['camera'] = [0, 5]
    elif (action_index == 2):
      action['forward'] = 1

    action['jump'] = 1
    action['attack'] = 1
    return action, action_index

episode_durations = []


def plot_durations():
    plt.figure(2)
    plt.clf()
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        display.clear_output(wait=True)
        display.display(plt.gcf())

def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)

    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1)[0].
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

num_episodes = 50
for i_episode in range(num_episodes):
    # Initialize the environment and state
    state = converter(obs)
    for t in count():
        # Select and perform an action
        action, action_index = select_action(state)
        obs, reward, done, _ = env.step(action)
        reward = torch.tensor([reward], device=device)

        # Observe new state
        next_state = converter(obs)

        # Store the transition in memory
        memory.push(state, action_index, next_state, reward)

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the target network)
        optimize_model()
        if done:
            episode_durations.append(t + 1)
            plot_durations()
            break
    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())
# Out:
# INFO:minerl.env.malmo.instance.04033f:Starting Minecraft process: ['/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/launchClient.sh', '-port', '12602', '-env', '-runDir', '/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/run']
# INFO:minerl.env.malmo.instance.04033f:Starting process watcher for process 41326 @ localhost:12602
# env: DISPLAY=:99
# DEBUG:minerl.env.malmo.instance.04033f:This mapping 'snapshot_20161220' was designed for MC 1.11! Use at your own peril.
# DEBUG:minerl.env.malmo.instance.04033f:#################################################
# DEBUG:minerl.env.malmo.instance.04033f:         ForgeGradle 2.2-SNAPSHOT-3966cea
# DEBUG:minerl.env.malmo.instance.04033f:  https://github.com/MinecraftForge/ForgeGradle
# DEBUG:minerl.env.malmo.instance.04033f:#################################################
# DEBUG:minerl.env.malmo.instance.04033f:               Powered by MCP unknown
# DEBUG:minerl.env.malmo.instance.04033f:             http://modcoderpack.com
# DEBUG:minerl.env.malmo.instance.04033f:         by: Searge, ProfMobius, Fesh0r,
# DEBUG:minerl.env.malmo.instance.04033f:         R4wk, ZeuX, IngisKahn, bspkrs
# DEBUG:minerl.env.malmo.instance.04033f:#################################################
# DEBUG:minerl.env.malmo.instance.04033f:Found AccessTransformer: malmomod_at.cfg
# DEBUG:minerl.env.malmo.instance.04033f::deobfCompileDummyTask
# DEBUG:minerl.env.malmo.instance.04033f::deobfProvidedDummyTask
# DEBUG:minerl.env.malmo.instance.04033f::getVersionJson
# DEBUG:minerl.env.malmo.instance.04033f::extractUserdev
# DEBUG:minerl.env.malmo.instance.04033f::downloadClient SKIPPED
# DEBUG:minerl.env.malmo.instance.04033f::downloadServer SKIPPED
# DEBUG:minerl.env.malmo.instance.04033f::splitServerJar SKIPPED
# DEBUG:minerl.env.malmo.instance.04033f::mergeJars SKIPPED
# DEBUG:minerl.env.malmo.instance.04033f::applyBinaryPatches
# DEBUG:minerl.env.malmo.instance.04033f::extractDependencyATs SKIPPED
# DEBUG:minerl.env.malmo.instance.04033f::extractMcpData SKIPPED
# DEBUG:minerl.env.malmo.instance.04033f::extractMcpMappings SKIPPED
# DEBUG:minerl.env.malmo.instance.04033f::genSrgs SKIPPED
# DEBUG:minerl.env.malmo.instance.04033f::deobfMcMCP
# DEBUG:minerl.env.malmo.instance.04033f:Applying SpecialSource...
# DEBUG:minerl.env.malmo.instance.04033f:Applying Exceptor...
# DEBUG:minerl.env.malmo.instance.04033f:Applying RuntimeInvisibleParameterAnnotations workaround...
# DEBUG:minerl.env.malmo.instance.04033f::sourceApiJava
# DEBUG:minerl.env.malmo.instance.04033f::compileApiJava UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.04033f::processApiResources UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.04033f::apiClasses UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.04033f::copyModToClient UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.04033f::copyModToServer UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.04033f::copySrg
# DEBUG:minerl.env.malmo.instance.04033f::deleteSchemas
# DEBUG:minerl.env.malmo.instance.04033f::copySchemas
# DEBUG:minerl.env.malmo.instance.04033f::jaxb
# DEBUG:minerl.env.malmo.instance.04033f::sourceMainJava
# DEBUG:minerl.env.malmo.instance.04033f::compileJavawarning: [options] bootstrap class path not set in conjunction with -source 1.6
# DEBUG:minerl.env.malmo.instance.04033f:Note: SpongePowered MIXIN Annotation Processor Version=0.7.5
# DEBUG:minerl.env.malmo.instance.04033f:Note: ObfuscationServiceMCP supports type: "searge"
# DEBUG:minerl.env.malmo.instance.04033f:Note: ObfuscationServiceMCP supports type: "notch"
# DEBUG:minerl.env.malmo.instance.04033f:Note: Loading searge mappings from /Users/maxrudolph/.gradle/caches/minecraft/de/oceanlabs/mcp/mcp_snapshot/20161220/1.11.2/srgs/mcp-srg.srg
# DEBUG:minerl.env.malmo.instance.04033f:Note: Loading notch mappings from /Users/maxrudolph/.gradle/caches/minecraft/de/oceanlabs/mcp/mcp_snapshot/20161220/1.11.2/srgs/mcp-notch.srg
# DEBUG:minerl.env.malmo.instance.04033f:Note: Writing refmap to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/tmp/compileJava/compileJava-refmap.json
# DEBUG:minerl.env.malmo.instance.04033f:Note: Writing refmap to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/tmp/compileJava/compileJava-refmap.json
# DEBUG:minerl.env.malmo.instance.04033f:Note: Writing searge output SRGs to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/tmp/compileJava/mcp-srg.srg
# DEBUG:minerl.env.malmo.instance.04033f:Note: Writing notch output SRGs to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/tmp/compileJava/mcp-notch.srg
# DEBUG:minerl.env.malmo.instance.04033f:Note: Writing refmap to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/tmp/compileJava/compileJava-refmap.json
# DEBUG:minerl.env.malmo.instance.04033f:Note: Writing refmap to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/tmp/compileJava/compileJava-refmap.json
# DEBUG:minerl.env.malmo.instance.04033f:Note: Writing searge output SRGs to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/tmp/compileJava/mcp-srg.srg
# DEBUG:minerl.env.malmo.instance.04033f:Note: Writing notch output SRGs to /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/tmp/compileJava/mcp-notch.srg
# DEBUG:minerl.env.malmo.instance.04033f:Note: Some input files use or override a deprecated API.
# DEBUG:minerl.env.malmo.instance.04033f:Note: Recompile with -Xlint:deprecation for details.
# DEBUG:minerl.env.malmo.instance.04033f:Note: Some input files use unchecked or unsafe operations.
# DEBUG:minerl.env.malmo.instance.04033f:Note: Recompile with -Xlint:unchecked for details.
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f::processResources
# DEBUG:minerl.env.malmo.instance.04033f::classes
# DEBUG:minerl.env.malmo.instance.04033f::jar
# DEBUG:minerl.env.malmo.instance.04033f::extractNatives SKIPPED
# DEBUG:minerl.env.malmo.instance.04033f::getAssetIndex UP-TO-DATE
# DEBUG:minerl.env.malmo.instance.04033f::getAssets
# DEBUG:minerl.env.malmo.instance.04033f::makeStart SKIPPED
# DEBUG:minerl.env.malmo.instance.04033f::runClient
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Extra: []
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Found and added coremod: com.microsoft.Malmo.OverclockingPlugin
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Running with arguments: [--userProperties, {}, --assetsDir, /Users/maxrudolph/.gradle/caches/minecraft/assets, --assetIndex, 1.11, --accessToken{REDACTED}, --version, 1.11.2, --tweakClass, net.minecraftforge.fml.common.launcher.FMLTweaker, --tweakClass, net.minecraftforge.gradle.tweakers.CoremodTweaker]
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Loading tweak class name net.minecraftforge.fml.common.launcher.FMLTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Using primary tweak class name net.minecraftforge.fml.common.launcher.FMLTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Loading tweak class name net.minecraftforge.gradle.tweakers.CoremodTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Calling tweak class net.minecraftforge.fml.common.launcher.FMLTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Forge Mod Loader version 13.20.0.2228 for Minecraft 1.11.2 loading
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Java is OpenJDK 64-Bit Server VM, version 1.8.0_272, running on Mac OS X:x86_64:10.15.7, installed at /Library/Java/JavaVirtualMachines/adoptopenjdk-8.jdk/Contents/Home/jre
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Managed to load a deobfuscated Minecraft name- we are in a deobfuscated environment. Skipping runtime deobfuscation
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Found a command line coremod : com.microsoft.Malmo.OverclockingPlugin
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/WARN]: The coremod com.microsoft.Malmo.OverclockingPlugin does not have a MCVersion annotation, it may cause issues with this version of Minecraft
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: SpongePowered MIXIN Subsystem Version=0.7.5 Source=file:/Users/maxrudolph/.gradle/caches/modules-2/files-2.1/org.spongepowered/mixin/0.7.5-SNAPSHOT/c989878008c2c5ff1a7c6491c4103d8faa221d19/mixin-0.7.5-SNAPSHOT.jar Service=LaunchWrapper Env=CLIENT
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Compatibility level set to JAVA_8
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Calling tweak class net.minecraftforge.gradle.tweakers.CoremodTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Injecting location in coremod net.minecraftforge.fml.relauncher.FMLCorePlugin
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Injecting location in coremod net.minecraftforge.classloading.FMLForgePlugin
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Injecting location in coremod com.microsoft.Malmo.OverclockingPlugin
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Loading tweak class name net.minecraftforge.fml.common.launcher.FMLInjectionAndSortingTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Loading tweak class name org.spongepowered.asm.mixin.EnvironmentStateTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Loading tweak class name net.minecraftforge.fml.common.launcher.FMLDeobfTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Loading tweak class name net.minecraftforge.gradle.tweakers.AccessTransformerTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Calling tweak class net.minecraftforge.fml.common.launcher.FMLInjectionAndSortingTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Calling tweak class net.minecraftforge.fml.common.launcher.FMLInjectionAndSortingTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/INFO]: Calling tweak class net.minecraftforge.fml.relauncher.CoreModManager$FMLPluginWrapper
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:31] [main/ERROR]: The binary patch set is missing. Either you are in a development environment, or things are not going to work!
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/ERROR]: FML appears to be missing any signature data. This is not a good thing
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: Calling tweak class net.minecraftforge.fml.relauncher.CoreModManager$FMLPluginWrapper
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: Calling tweak class net.minecraftforge.fml.relauncher.CoreModManager$FMLPluginWrapper
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: Calling tweak class org.spongepowered.asm.mixin.EnvironmentStateTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: Initialised Mixin FML Remapper Adapter with net.minecraftforge.fml.common.asm.transformers.deobf.FMLDeobfuscatingRemapper@75201592
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: Calling tweak class net.minecraftforge.fml.common.launcher.FMLDeobfTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: Calling tweak class net.minecraftforge.gradle.tweakers.AccessTransformerTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: Loading tweak class name net.minecraftforge.fml.common.launcher.TerminalTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: Calling tweak class net.minecraftforge.fml.common.launcher.TerminalTweaker
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/WARN]: Reference map 'mixins.replaymod.refmap.json' for mixins.overclocking.malmomod.json could not be read. If this is a development environment you can ignore this message
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:transform:58]: MALMO: Attempting to transform MinecraftServer
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:129]: MALMO: Found Minecraft, attempting to transform it
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:135]: MALMO: Found Minecraft.runGameLoop() method, attempting to transform it
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:150]: MALMO: Hooked into call to Minecraft.updateDisplay()
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: A re-entrant transformer '$wrapper.com.microsoft.Malmo.OverclockingClassTransformer' was detected and will no longer process meta class data
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: Launching wrapped minecraft {net.minecraft.client.main.Main}
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:transform:58]: MALMO: Attempting to transform MinecraftServer
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:129]: MALMO: Found Minecraft, attempting to transform it
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:135]: MALMO: Found Minecraft.runGameLoop() method, attempting to transform it
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:32] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:overclockRenderer:150]: MALMO: Hooked into call to Minecraft.updateDisplay()
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:33] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:transform:42]: Transformed Name: net.minecraft.client.entity.EntityPlayerSP
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:33] [main/INFO]: [com.microsoft.Malmo.OverclockingClassTransformer:transform:42]: Transformed Name: net.minecraft.client.entity.AbstractClientPlayer
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:33] [Client thread/INFO]: Setting user: Player481
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:35] [Client thread/WARN]: Skipping bad option: lastServer:
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:35] [Client thread/INFO]: LWJGL Version: 2.9.2
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:36] [Client thread/INFO]: [STDOUT]: MALMO: Attempting to transform MinecraftServer
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:36] [Client thread/INFO]: [STDOUT]: MALMO: Found GlStateManager, attempting to transform it
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:36] [Client thread/INFO]: [STDOUT]: MALMO: Found GlStateManager.bindTexture() method, attempting to transform it
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:36] [Client thread/INFO]: [STDOUT]: MALMO: Hooked into call to GlStateManager.bindTexture()
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:36] [Client thread/INFO]: MinecraftForge v13.20.0.2228 Initialized
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:36] [Client thread/INFO]: Replaced 232 ore recipes
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:36] [Client thread/INFO]: Found 0 mods from the command line. Injecting into mod discoverer
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:36] [Client thread/INFO]: Searching /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/run/mods for mods
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:37] [Client thread/INFO]: Forge Mod Loader has identified 5 mods to load
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:37] [Client thread/INFO]: Attempting connection with missing mods [minecraft, mcp, FML, forge, malmomod] at CLIENT
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:37] [Client thread/INFO]: Attempting connection with missing mods [minecraft, mcp, FML, forge, malmomod] at SERVER
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Reloading ResourceManager: Default, FMLFileResourcePack:Forge Mod Loader, FMLFileResourcePack:Minecraft Forge, FMLFileResourcePack:Microsoft Malmo Mod
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Processing ObjectHolder annotations
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Found 444 ObjectHolder annotations
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Identifying ItemStackHolder annotations
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Found 0 ItemStackHolder annotations
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Applying holder lookups
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Holder lookups applied
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Applying holder lookups
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Holder lookups applied
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Applying holder lookups
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Holder lookups applied
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Configured a dormant chunk cache size of 0
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Forge Version Check/INFO]: [forge] Starting version check at http://files.minecraftforge.net/maven/net/minecraftforge/forge/promotions_slim.json
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: [STDOUT]: Testing schemas against internal version number: 0.37
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: [STDOUT]: [LOGTOPY] Performance directory not specified.
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: [STDOUT]: [ERROR] Seed specified was NONE. Expected a long (integer).
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Forge Version Check/INFO]: [forge] Found status: OUTDATED Target: 13.20.1.2386
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Applying holder lookups
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Holder lookups applied
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Injecting itemstacks
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:38] [Client thread/INFO]: Itemstack injection complete
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:39] [Sound Library Loader/INFO]: Starting up SoundSystem...
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:39] [Thread-5/INFO]: Initializing LWJGL OpenAL
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:39] [Thread-5/INFO]: (The LWJGL binding of OpenAL.  For more information, see http://www.lwjgl.org)
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:39] [Thread-5/INFO]: OpenAL initialized.
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:40] [Sound Library Loader/INFO]: Sound engine started
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:41] [Client thread/INFO]: Max texture size: 16384
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:41] [Client thread/INFO]: Created: 16x16 textures-atlas
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:42] [Client thread/INFO]: [STDOUT]: CLIENT request state: WAITING_FOR_MOD_READY
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:42] [Client thread/INFO]: Injecting itemstacks
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:42] [Client thread/INFO]: Itemstack injection complete
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:42] [Client thread/INFO]: Forge Mod Loader has successfully loaded 5 mods
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:42] [Client thread/INFO]: Reloading ResourceManager: Default, FMLFileResourcePack:Forge Mod Loader, FMLFileResourcePack:Minecraft Forge, FMLFileResourcePack:Microsoft Malmo Mod
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:42] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:42] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:42] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /private/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmpd958h1ln/Minecraft/build/libs/MalmoMod-0.37.0.jar
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:43] [Client thread/INFO]: SoundSystem shutting down...
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:43] [Client thread/WARN]: Author: Paul Lamb, www.paulscode.com
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:43] [Sound Library Loader/INFO]: Starting up SoundSystem...
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:43] [Thread-7/INFO]: Initializing LWJGL OpenAL
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:43] [Thread-7/INFO]: (The LWJGL binding of OpenAL.  For more information, see http://www.lwjgl.org)
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:43] [Thread-7/INFO]: OpenAL initialized.
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:44] [Sound Library Loader/INFO]: Sound engine started
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:44] [Client thread/INFO]: Max texture size: 16384
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:44] [Client thread/INFO]: Created: 512x512 textures-atlas
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:45] [Client thread/WARN]: Skipping bad option: lastServer:
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:45] [Client thread/INFO]: [STDOUT]: CLIENT enter state: WAITING_FOR_MOD_READY
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:45] [Client thread/INFO]: [STDOUT]: ***** Start MalmoEnvServer on port 12602
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:45] [Client thread/INFO]: [STDOUT]: CLIENT request state: DORMANT
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:45] [Client thread/INFO]: [STDOUT]: CLIENT enter state: DORMANT
# INFO:minerl.env.malmo.instance.04033f:Minecraft process ready
# INFO:minerl.env.malmo:Logging output of Minecraft to ./logs/mc_3602.log
# DEBUG:minerl.env.core:Creating socket connection!
# DEBUG:minerl.env.core:Sending mission init!
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:46] [EnvServerSocketHandler/INFO]: [STDOUT]: Received from localhost:<MissionInit xmlns="http://ProjectMalmo.microsoft.com" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" SchemaVersion="" PlatformVersion="0.37.0">
# DEBUG:minerl.env.malmo.instance.04033f:                                <Mission>
# DEBUG:minerl.env.malmo.instance.04033f:    <About>
# DEBUG:minerl.env.malmo.instance.04033f:        <Summary>MineRLNavigateDense-v0</Summary>
# DEBUG:minerl.env.malmo.instance.04033f:    </About>
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:    <ModSettings>
# DEBUG:minerl.env.malmo.instance.04033f:        <MsPerTick>50</MsPerTick>
# DEBUG:minerl.env.malmo.instance.04033f:    </ModSettings>
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:    <ServerSection>
# DEBUG:minerl.env.malmo.instance.04033f:        <ServerInitialConditions>
# DEBUG:minerl.env.malmo.instance.04033f:            <Time>
# DEBUG:minerl.env.malmo.instance.04033f:                <StartTime>6000</StartTime>
# DEBUG:minerl.env.malmo.instance.04033f:                <AllowPassageOfTime>false</AllowPassageOfTime>
# DEBUG:minerl.env.malmo.instance.04033f:            </Time>
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:            <Weather>clear</Weather>
# DEBUG:minerl.env.malmo.instance.04033f:            <AllowSpawning>false</AllowSpawning>
# DEBUG:minerl.env.malmo.instance.04033f:        </ServerInitialConditions>
# DEBUG:minerl.env.malmo.instance.04033f:        <ServerHandlers>
# DEBUG:minerl.env.malmo.instance.04033f:            <DefaultWorldGenerator forceReset="true"/>
# DEBUG:minerl.env.malmo.instance.04033f:            <NavigationDecorator>
# DEBUG:minerl.env.malmo.instance.04033f:                <randomPlacementProperties>
# DEBUG:minerl.env.malmo.instance.04033f:                    <maxRandomizedRadius>64</maxRandomizedRadius>
# DEBUG:minerl.env.malmo.instance.04033f:                    <minRandomizedRadius>64</minRandomizedRadius>
# DEBUG:minerl.env.malmo.instance.04033f:                    <maxRadius>8</maxRadius>
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:46] [EnvServerSocketHandler/INFO]: [STDOUT]: REPLYING WITH: MALMOOK
# DEBUG:minerl.env.core:Peeking the client.
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:46] [Client thread/INFO]: [STDOUT]: Mission received: MineRLNavigateDense-v0
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:46] [Client thread/INFO]: [STDOUT]: CLIENT request state: CREATING_HANDLERS
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:46] [Client thread/INFO]: [STDOUT]: CLIENT enter state: CREATING_HANDLERS
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:46] [Client thread/INFO]: [STDOUT]: Starting command server.
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:46] [Thread-10/INFO]: [STDOUT]: INFO: ->com(0) Listening for messages on port 10724
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:47] [Client thread/INFO]: [STDOUT]: CLIENT request state: EVALUATING_WORLD_REQUIREMENTS
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:47] [Client thread/INFO]: [STDOUT]: CLIENT enter state: EVALUATING_WORLD_REQUIREMENTS
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:47] [Client thread/INFO]: [STDOUT]: CLIENT request state: CREATING_NEW_WORLD
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:47] [Client thread/INFO]: [STDOUT]: CLIENT enter state: CREATING_NEW_WORLD
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:47] [Server thread/INFO]: Starting integrated minecraft server version 1.11.2
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:47] [Server thread/INFO]: Generating keypair
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:47] [Server thread/INFO]: Injecting existing block and item data into this server instance
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:47] [Server thread/INFO]: Applying holder lookups
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:47] [Server thread/INFO]: Holder lookups applied
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:47] [Server thread/INFO]: Loading dimension 0 (TEMP_0_c06243a8-4dde-45e2-8c4e-bd3a820a4668) (net.minecraft.server.integrated.IntegratedServer@5752304b)
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:48] [Server thread/INFO]: Loading dimension 1 (TEMP_0_c06243a8-4dde-45e2-8c4e-bd3a820a4668) (net.minecraft.server.integrated.IntegratedServer@5752304b)
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:48] [Server thread/INFO]: Loading dimension -1 (TEMP_0_c06243a8-4dde-45e2-8c4e-bd3a820a4668) (net.minecraft.server.integrated.IntegratedServer@5752304b)
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:48] [Server thread/INFO]: Preparing start region for level 0
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:48] [Realms Notification Availability checker #1/INFO]: Could not authorize you against Realms server: Invalid session id
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:49] [Server thread/INFO]: Preparing spawn area: 10%
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:50] [Server thread/INFO]: Preparing spawn area: 21%
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:51] [Server thread/INFO]: Preparing spawn area: 34%
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:52] [Server thread/INFO]: Preparing spawn area: 49%
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:53] [Server thread/INFO]: Preparing spawn area: 66%
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:54] [Server thread/INFO]: Preparing spawn area: 82%
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:55] [Server thread/INFO]: Preparing spawn area: 98%
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:55] [Server thread/INFO]: Changing view distance to 4, from 10
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Netty Local Client IO #0/INFO]: [STDOUT]: Transformed Name: net.minecraft.client.entity.EntityOtherPlayerMP
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Netty Local Client IO #0/INFO]: [STDOUT]: MALMO: Attempting to transform MinecraftServer
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Netty Local Client IO #0/INFO]: [STDOUT]: MALMO: Found EntityOtherPlayerMP, attempting to transform it
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [STDOUT]: SERVER request state: WAITING_FOR_MOD_READY
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [STDOUT]: CLIENT request state: WAITING_FOR_SERVER_READY
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [STDOUT]: SERVER enter state: WAITING_FOR_MOD_READY
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Client thread/INFO]: [STDOUT]: CLIENT enter state: WAITING_FOR_SERVER_READY
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Netty Local Client IO #0/INFO]: Server protocol version 2
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Netty Server IO #1/INFO]: Client protocol version 2
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Netty Server IO #1/INFO]: Client attempting to join with 5 mods : minecraft@1.11.2,FML@8.0.99.99,malmomod@0.37.0,forge@13.20.0.2228,mcp@9.19
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Netty Local Client IO #0/INFO]: [Netty Local Client IO #0] Client side modded connection established
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [Server thread] Server side modded connection established
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: MineRLAgent[local:E:1504bbe6] logged in with entity id 845 at (-160.5, 72.0, 70.5)
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: MineRLAgent joined the game
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [STDOUT]: SERVER request state: DORMANT
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [STDOUT]: SERVER enter state: DORMANT
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [STDOUT]: INCOMING MISSION: Received MissionInit directly through ServerStateMachine constructor.
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [STDOUT]: Mission received: MineRLNavigateDense-v0
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: Received mission: §9MineRLNavigateDense-v0
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: Source: §alocalhost
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [STDOUT]: SERVER request state: BUILDING_WORLD
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [STDOUT]: SERVER enter state: BUILDING_WORLD
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:56] [Server thread/INFO]: [STDOUT]: SERVER request state: WAITING_FOR_AGENTS_TO_ASSEMBLE
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:57] [Client thread/INFO]: [STDOUT]: ***Telling server we are ready - MineRLAgent
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:57] [Server thread/INFO]: [STDOUT]: SERVER enter state: WAITING_FOR_AGENTS_TO_ASSEMBLE
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:57] [Server thread/INFO]: [STDOUT]: Experiment requires:
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:57] [Server thread/INFO]: [STDOUT]: >>>> MineRLAgent
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:57] [Client thread/INFO]: [CHAT] Received mission: §9MineRLNavigateDense-v0
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:57] [Client thread/INFO]: [CHAT] Source: §alocalhost
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:57] [Client thread/INFO]: [STDOUT]: ***Telling server we are ready - MineRLAgent
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:58] [Client thread/INFO]: [STDOUT]: CLIENT request state: RUNNING
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:58] [Client thread/INFO]: [STDOUT]: CLIENT enter state: RUNNING
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:58] [Server thread/INFO]: [STDOUT]: SERVER request state: RUNNING
# DEBUG:minerl.env.malmo.instance.04033f:[13:24:58] [Client thread/INFO]: [STDOUT]: Resized the window
# DEBUG:minerl.env.malmo.instance.04033f:2020-11-14 13:24:58.117 java[41346:5632025] *** Terminating app due to uncaught exception 'NSInternalInconsistencyException', reason: 'NSWindow drag regions should only be invalidated on the Main Thread!'
# DEBUG:minerl.env.malmo.instance.04033f:*** First throw call stack:
# DEBUG:minerl.env.comms:Pause before retry on 'NoneType' object has no attribute 'decode'
# DEBUG:minerl.env.malmo.instance.04033f:(
# DEBUG:minerl.env.malmo.instance.04033f:	0   CoreFoundation                      0x00007fff32964b57 __exceptionPreprocess + 250
# DEBUG:minerl.env.malmo.instance.04033f:	1   libobjc.A.dylib                     0x00007fff6b7b05bf objc_exception_throw + 48
# DEBUG:minerl.env.malmo.instance.04033f:	2   CoreFoundation                      0x00007fff3298d34c -[NSException raise] + 9
# DEBUG:minerl.env.malmo.instance.04033f:	3   AppKit                              0x00007fff2fb875ec -[NSWindow(NSWindow_Theme) _postWindowNeedsToResetDragMarginsUnlessPostingDisabled] + 310
# DEBUG:minerl.env.malmo.instance.04033f:	4   AppKit                              0x00007fff2fbb1cee -[NSThemeFrame setStyleMask:] + 137
# DEBUG:minerl.env.malmo.instance.04033f:	5   AppKit                              0x00007fff2fbb1b3c __25-[NSWindow setStyleMask:]_block_invoke + 1908
# DEBUG:minerl.env.malmo.instance.04033f:	6   AppKit                              0x00007fff2fbb136e NSPerformVisuallyAtomicChange + 132
# DEBUG:minerl.env.malmo.instance.04033f:	7   AppKit                              0x00007fff2fbb1279 -[NSWindow setStyleMask:] + 184
# DEBUG:minerl.env.malmo.instance.04033f:	8   liblwjgl.dylib                      0x000000012ba07ee2 Java_org_lwjgl_opengl_MacOSXDisplay_nSetResizable + 82
# DEBUG:minerl.env.malmo.instance.04033f:	9   ???                                 0x0000000116abe407 0x0 + 4675331079
# DEBUG:minerl.env.malmo.instance.04033f:)
# DEBUG:minerl.env.malmo.instance.04033f:libc++abi.dylib: terminating with uncaught exception of type NSException
# DEBUG:minerl.env.malmo.instance.04033f::runClient FAILED
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:FAILURE: Build failed with an exception.
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:* What went wrong:
# DEBUG:minerl.env.malmo.instance.04033f:Execution failed for task ':runClient'.
# DEBUG:minerl.env.malmo.instance.04033f:> Process 'command '/Library/Java/JavaVirtualMachines/adoptopenjdk-8.jdk/Contents/Home/bin/java'' finished with non-zero exit value 134
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:* Try:
# DEBUG:minerl.env.malmo.instance.04033f:Run with --info or --debug option to get more log output.
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:* Exception is:
# DEBUG:minerl.env.malmo.instance.04033f:org.gradle.api.tasks.TaskExecutionException: Execution failed for task ':runClient'.
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.executeActions(ExecuteActionsTaskExecuter.java:69)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.execute(ExecuteActionsTaskExecuter.java:46)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.PostExecutionAnalysisTaskExecuter.execute(PostExecutionAnalysisTaskExecuter.java:35)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.SkipUpToDateTaskExecuter.execute(SkipUpToDateTaskExecuter.java:66)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.ValidatingTaskExecuter.execute(ValidatingTaskExecuter.java:58)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.SkipEmptySourceFilesTaskExecuter.execute(SkipEmptySourceFilesTaskExecuter.java:52)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.SkipTaskWithNoActionsExecuter.execute(SkipTaskWithNoActionsExecuter.java:52)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.SkipOnlyIfTaskExecuter.execute(SkipOnlyIfTaskExecuter.java:53)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.ExecuteAtMostOnceTaskExecuter.execute(ExecuteAtMostOnceTaskExecuter.java:43)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.taskgraph.DefaultTaskGraphExecuter$EventFiringTaskWorker.execute(DefaultTaskGraphExecuter.java:203)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.taskgraph.DefaultTaskGraphExecuter$EventFiringTaskWorker.execute(DefaultTaskGraphExecuter.java:185)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.taskgraph.AbstractTaskPlanExecutor$TaskExecutorWorker.processTask(AbstractTaskPlanExecutor.java:66)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.taskgraph.AbstractTaskPlanExecutor$TaskExecutorWorker.run(AbstractTaskPlanExecutor.java:50)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.taskgraph.DefaultTaskPlanExecutor.process(DefaultTaskPlanExecutor.java:25)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.taskgraph.DefaultTaskGraphExecuter.execute(DefaultTaskGraphExecuter.java:110)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.SelectedTaskExecutionAction.execute(SelectedTaskExecutionAction.java:37)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.DefaultBuildExecuter.execute(DefaultBuildExecuter.java:37)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.DefaultBuildExecuter.access$000(DefaultBuildExecuter.java:23)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.DefaultBuildExecuter$1.proceed(DefaultBuildExecuter.java:43)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.DryRunBuildExecutionAction.execute(DryRunBuildExecutionAction.java:32)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.DefaultBuildExecuter.execute(DefaultBuildExecuter.java:37)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.execution.DefaultBuildExecuter.execute(DefaultBuildExecuter.java:30)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.initialization.DefaultGradleLauncher$4.run(DefaultGradleLauncher.java:153)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.internal.Factories$1.create(Factories.java:22)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:91)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:53)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.initialization.DefaultGradleLauncher.doBuildStages(DefaultGradleLauncher.java:150)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.initialization.DefaultGradleLauncher.access$200(DefaultGradleLauncher.java:32)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.initialization.DefaultGradleLauncher$1.create(DefaultGradleLauncher.java:98)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.initialization.DefaultGradleLauncher$1.create(DefaultGradleLauncher.java:92)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:91)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:63)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.initialization.DefaultGradleLauncher.doBuild(DefaultGradleLauncher.java:92)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.initialization.DefaultGradleLauncher.run(DefaultGradleLauncher.java:83)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.exec.InProcessBuildActionExecuter$DefaultBuildController.run(InProcessBuildActionExecuter.java:99)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.tooling.internal.provider.ExecuteBuildActionRunner.run(ExecuteBuildActionRunner.java:28)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.exec.ChainingBuildActionRunner.run(ChainingBuildActionRunner.java:35)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.exec.InProcessBuildActionExecuter.execute(InProcessBuildActionExecuter.java:48)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.exec.InProcessBuildActionExecuter.execute(InProcessBuildActionExecuter.java:30)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.exec.ContinuousBuildActionExecuter.execute(ContinuousBuildActionExecuter.java:81)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.exec.ContinuousBuildActionExecuter.execute(ContinuousBuildActionExecuter.java:46)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.exec.DaemonUsageSuggestingBuildActionExecuter.execute(DaemonUsageSuggestingBuildActionExecuter.java:51)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.exec.DaemonUsageSuggestingBuildActionExecuter.execute(DaemonUsageSuggestingBuildActionExecuter.java:28)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.cli.RunBuildAction.run(RunBuildAction.java:43)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.internal.Actions$RunnableActionAdapter.execute(Actions.java:173)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.cli.CommandLineActionFactory$ParseAndBuildAction.execute(CommandLineActionFactory.java:239)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.cli.CommandLineActionFactory$ParseAndBuildAction.execute(CommandLineActionFactory.java:212)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.cli.JavaRuntimeValidationAction.execute(JavaRuntimeValidationAction.java:35)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.cli.JavaRuntimeValidationAction.execute(JavaRuntimeValidationAction.java:24)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.cli.ExceptionReportingAction.execute(ExceptionReportingAction.java:33)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.cli.ExceptionReportingAction.execute(ExceptionReportingAction.java:22)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.cli.CommandLineActionFactory$WithLogging.execute(CommandLineActionFactory.java:205)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.cli.CommandLineActionFactory$WithLogging.execute(CommandLineActionFactory.java:169)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.Main.doAction(Main.java:33)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.bootstrap.EntryPoint.run(EntryPoint.java:45)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.bootstrap.ProcessBootstrap.runNoExit(ProcessBootstrap.java:55)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.bootstrap.ProcessBootstrap.run(ProcessBootstrap.java:36)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.launcher.GradleMain.main(GradleMain.java:23)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.wrapper.BootstrapMainStarter.start(BootstrapMainStarter.java:30)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.wrapper.WrapperExecutor.execute(WrapperExecutor.java:127)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.wrapper.GradleWrapperMain.main(GradleWrapperMain.java:61)
# DEBUG:minerl.env.malmo.instance.04033f:Caused by: org.gradle.process.internal.ExecException: Process 'command '/Library/Java/JavaVirtualMachines/adoptopenjdk-8.jdk/Contents/Home/bin/java'' finished with non-zero exit value 134
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.process.internal.DefaultExecHandle$ExecResultImpl.assertNormalExitValue(DefaultExecHandle.java:367)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.process.internal.DefaultJavaExecAction.execute(DefaultJavaExecAction.java:31)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.tasks.JavaExec.exec(JavaExec.java:74)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.internal.reflect.JavaMethod.invoke(JavaMethod.java:75)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.project.taskfactory.AnnotationProcessingTaskFactory$StandardTaskAction.doExecute(AnnotationProcessingTaskFactory.java:228)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.project.taskfactory.AnnotationProcessingTaskFactory$StandardTaskAction.execute(AnnotationProcessingTaskFactory.java:221)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.project.taskfactory.AnnotationProcessingTaskFactory$StandardTaskAction.execute(AnnotationProcessingTaskFactory.java:210)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.AbstractTask$TaskActionWrapper.execute(AbstractTask.java:621)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.AbstractTask$TaskActionWrapper.execute(AbstractTask.java:604)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.executeAction(ExecuteActionsTaskExecuter.java:80)
# DEBUG:minerl.env.malmo.instance.04033f:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.executeActions(ExecuteActionsTaskExecuter.java:61)
# DEBUG:minerl.env.malmo.instance.04033f:	... 60 more
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:BUILD FAILED
# DEBUG:minerl.env.malmo.instance.04033f:
# DEBUG:minerl.env.malmo.instance.04033f:Total time: 52.034 secs
# DEBUG:minerl.env.comms:Pause complete.
# DEBUG:minerl.env.core:Sending mission init!
# ERROR:minerl.env.core:Failed to reset (socket error), trying again!
# ERROR:minerl.env.core:Cleaning connection! Something must have gone wrong.
# DEBUG:minerl.env.comms:Pause before retry on [Errno 54] Connection reset by peer
# DEBUG:minerl.env.comms:Pause complete.
# DEBUG:minerl.env.core:Creating socket connection!
# ERROR:minerl.env.core:Failed to reset (socket error), trying again!
# ERROR:minerl.env.core:Cleaning connection! Something must have gone wrong.
# ERROR:minerl.env.core:Connection with Minecraft client cleaned more than once; restarting.
# ERROR:minerl.env.malmo:Attempted to send kill command to minecraft process and failed.
# INFO:minerl.env.malmo:Minecraft process psutil.Process(pid=41326, status='terminated', exitcode=0, started='13:24:06') terminated with exit code 0
# INFO:minerl.env.malmo.instance.7303d4:Starting Minecraft process: ['/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmp1v9u1wmn/Minecraft/launchClient.sh', '-port', '12603', '-env', '-runDir', '/var/folders/_5/9n4k6nj50nb48gfy7_x3brnr0000gn/T/tmp1v9u1wmn/Minecraft/run']
# INFO:minerl.env.malmo.instance.7303d4:Starting process watcher for process 41376 @ localhost:12603
# DEBUG:minerl.env.malmo.instance.7303d4:This mapping 'snapshot_20161220' was designed for MC 1.11! Use at your own peril.
# DEBUG:minerl.env.malmo.instance.7303d4:#################################################
# ...
# DEBUG:minerl.env.malmo.instance.7303d4:[13:26:20] [Client thread/INFO]: [STDOUT]: Resized the window
# DEBUG:minerl.env.malmo.instance.7303d4:2020-11-14 13:26:20.150 java[41390:5634112] *** Terminating app due to uncaught exception 'NSInternalInconsistencyException', reason: 'NSWindow drag regions should only be invalidated on the Main Thread!'
# DEBUG:minerl.env.malmo.instance.7303d4:*** First throw call stack:
# DEBUG:minerl.env.comms:Pause before retry on 'NoneType' object has no attribute 'decode'
# DEBUG:minerl.env.malmo.instance.7303d4:(
# DEBUG:minerl.env.malmo.instance.7303d4:	0   CoreFoundation                      0x00007fff32964b57 __exceptionPreprocess + 250
# DEBUG:minerl.env.malmo.instance.7303d4:	1   libobjc.A.dylib                     0x00007fff6b7b05bf objc_exception_throw + 48
# DEBUG:minerl.env.malmo.instance.7303d4:	2   CoreFoundation                      0x00007fff3298d34c -[NSException raise] + 9
# DEBUG:minerl.env.malmo.instance.7303d4:	3   AppKit                              0x00007fff2fb875ec -[NSWindow(NSWindow_Theme) _postWindowNeedsToResetDragMarginsUnlessPostingDisabled] + 310
# DEBUG:minerl.env.malmo.instance.7303d4:	4   AppKit                              0x00007fff2fbb1cee -[NSThemeFrame setStyleMask:] + 137
# DEBUG:minerl.env.malmo.instance.7303d4:	5   AppKit                              0x00007fff2fbb1b3c __25-[NSWindow setStyleMask:]_block_invoke + 1908
# DEBUG:minerl.env.malmo.instance.7303d4:	6   AppKit                              0x00007fff2fbb136e NSPerformVisuallyAtomicChange + 132
# DEBUG:minerl.env.malmo.instance.7303d4:	7   AppKit                              0x00007fff2fbb1279 -[NSWindow setStyleMask:] + 184
# DEBUG:minerl.env.malmo.instance.7303d4:	8   liblwjgl.dylib                      0x00000001297edee2 Java_org_lwjgl_opengl_MacOSXDisplay_nSetResizable + 82
# DEBUG:minerl.env.malmo.instance.7303d4:	9   ???                                 0x00000001105ee407 0x0 + 4569621511
# DEBUG:minerl.env.malmo.instance.7303d4:)
# DEBUG:minerl.env.malmo.instance.7303d4:libc++abi.dylib: terminating with uncaught exception of type NSException
# DEBUG:minerl.env.malmo.instance.7303d4::runClient FAILED
# DEBUG:minerl.env.malmo.instance.7303d4:
# DEBUG:minerl.env.malmo.instance.7303d4:FAILURE: Build failed with an exception.
# DEBUG:minerl.env.malmo.instance.7303d4:
# DEBUG:minerl.env.malmo.instance.7303d4:* What went wrong:
# DEBUG:minerl.env.malmo.instance.7303d4:Execution failed for task ':runClient'.
# DEBUG:minerl.env.malmo.instance.7303d4:> Process 'command '/Library/Java/JavaVirtualMachines/adoptopenjdk-8.jdk/Contents/Home/bin/java'' finished with non-zero exit value 134
# DEBUG:minerl.env.malmo.instance.7303d4:
# DEBUG:minerl.env.malmo.instance.7303d4:* Try:
# DEBUG:minerl.env.malmo.instance.7303d4:Run with --info or --debug option to get more log output.
# DEBUG:minerl.env.malmo.instance.7303d4:
# DEBUG:minerl.env.malmo.instance.7303d4:* Exception is:
# DEBUG:minerl.env.malmo.instance.7303d4:org.gradle.api.tasks.TaskExecutionException: Execution failed for task ':runClient'.
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.executeActions(ExecuteActionsTaskExecuter.java:69)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.execute(ExecuteActionsTaskExecuter.java:46)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.PostExecutionAnalysisTaskExecuter.execute(PostExecutionAnalysisTaskExecuter.java:35)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.SkipUpToDateTaskExecuter.execute(SkipUpToDateTaskExecuter.java:66)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.ValidatingTaskExecuter.execute(ValidatingTaskExecuter.java:58)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.SkipEmptySourceFilesTaskExecuter.execute(SkipEmptySourceFilesTaskExecuter.java:52)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.SkipTaskWithNoActionsExecuter.execute(SkipTaskWithNoActionsExecuter.java:52)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.SkipOnlyIfTaskExecuter.execute(SkipOnlyIfTaskExecuter.java:53)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.ExecuteAtMostOnceTaskExecuter.execute(ExecuteAtMostOnceTaskExecuter.java:43)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.taskgraph.DefaultTaskGraphExecuter$EventFiringTaskWorker.execute(DefaultTaskGraphExecuter.java:203)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.taskgraph.DefaultTaskGraphExecuter$EventFiringTaskWorker.execute(DefaultTaskGraphExecuter.java:185)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.taskgraph.AbstractTaskPlanExecutor$TaskExecutorWorker.processTask(AbstractTaskPlanExecutor.java:66)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.taskgraph.AbstractTaskPlanExecutor$TaskExecutorWorker.run(AbstractTaskPlanExecutor.java:50)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.taskgraph.DefaultTaskPlanExecutor.process(DefaultTaskPlanExecutor.java:25)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.taskgraph.DefaultTaskGraphExecuter.execute(DefaultTaskGraphExecuter.java:110)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.SelectedTaskExecutionAction.execute(SelectedTaskExecutionAction.java:37)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.DefaultBuildExecuter.execute(DefaultBuildExecuter.java:37)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.DefaultBuildExecuter.access$000(DefaultBuildExecuter.java:23)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.DefaultBuildExecuter$1.proceed(DefaultBuildExecuter.java:43)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.DryRunBuildExecutionAction.execute(DryRunBuildExecutionAction.java:32)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.DefaultBuildExecuter.execute(DefaultBuildExecuter.java:37)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.execution.DefaultBuildExecuter.execute(DefaultBuildExecuter.java:30)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.initialization.DefaultGradleLauncher$4.run(DefaultGradleLauncher.java:153)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.internal.Factories$1.create(Factories.java:22)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:91)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:53)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.initialization.DefaultGradleLauncher.doBuildStages(DefaultGradleLauncher.java:150)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.initialization.DefaultGradleLauncher.access$200(DefaultGradleLauncher.java:32)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.initialization.DefaultGradleLauncher$1.create(DefaultGradleLauncher.java:98)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.initialization.DefaultGradleLauncher$1.create(DefaultGradleLauncher.java:92)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:91)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.internal.progress.DefaultBuildOperationExecutor.run(DefaultBuildOperationExecutor.java:63)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.initialization.DefaultGradleLauncher.doBuild(DefaultGradleLauncher.java:92)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.initialization.DefaultGradleLauncher.run(DefaultGradleLauncher.java:83)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.exec.InProcessBuildActionExecuter$DefaultBuildController.run(InProcessBuildActionExecuter.java:99)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.tooling.internal.provider.ExecuteBuildActionRunner.run(ExecuteBuildActionRunner.java:28)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.exec.ChainingBuildActionRunner.run(ChainingBuildActionRunner.java:35)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.exec.InProcessBuildActionExecuter.execute(InProcessBuildActionExecuter.java:48)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.exec.InProcessBuildActionExecuter.execute(InProcessBuildActionExecuter.java:30)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.exec.ContinuousBuildActionExecuter.execute(ContinuousBuildActionExecuter.java:81)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.exec.ContinuousBuildActionExecuter.execute(ContinuousBuildActionExecuter.java:46)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.exec.DaemonUsageSuggestingBuildActionExecuter.execute(DaemonUsageSuggestingBuildActionExecuter.java:51)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.exec.DaemonUsageSuggestingBuildActionExecuter.execute(DaemonUsageSuggestingBuildActionExecuter.java:28)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.cli.RunBuildAction.run(RunBuildAction.java:43)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.internal.Actions$RunnableActionAdapter.execute(Actions.java:173)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.cli.CommandLineActionFactory$ParseAndBuildAction.execute(CommandLineActionFactory.java:239)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.cli.CommandLineActionFactory$ParseAndBuildAction.execute(CommandLineActionFactory.java:212)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.cli.JavaRuntimeValidationAction.execute(JavaRuntimeValidationAction.java:35)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.cli.JavaRuntimeValidationAction.execute(JavaRuntimeValidationAction.java:24)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.cli.ExceptionReportingAction.execute(ExceptionReportingAction.java:33)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.cli.ExceptionReportingAction.execute(ExceptionReportingAction.java:22)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.cli.CommandLineActionFactory$WithLogging.execute(CommandLineActionFactory.java:205)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.cli.CommandLineActionFactory$WithLogging.execute(CommandLineActionFactory.java:169)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.Main.doAction(Main.java:33)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.bootstrap.EntryPoint.run(EntryPoint.java:45)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.bootstrap.ProcessBootstrap.runNoExit(ProcessBootstrap.java:55)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.bootstrap.ProcessBootstrap.run(ProcessBootstrap.java:36)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.launcher.GradleMain.main(GradleMain.java:23)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.wrapper.BootstrapMainStarter.start(BootstrapMainStarter.java:30)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.wrapper.WrapperExecutor.execute(WrapperExecutor.java:127)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.wrapper.GradleWrapperMain.main(GradleWrapperMain.java:61)
# DEBUG:minerl.env.malmo.instance.7303d4:Caused by: org.gradle.process.internal.ExecException: Process 'command '/Library/Java/JavaVirtualMachines/adoptopenjdk-8.jdk/Contents/Home/bin/java'' finished with non-zero exit value 134
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.process.internal.DefaultExecHandle$ExecResultImpl.assertNormalExitValue(DefaultExecHandle.java:367)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.process.internal.DefaultJavaExecAction.execute(DefaultJavaExecAction.java:31)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.tasks.JavaExec.exec(JavaExec.java:74)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.internal.reflect.JavaMethod.invoke(JavaMethod.java:75)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.project.taskfactory.AnnotationProcessingTaskFactory$StandardTaskAction.doExecute(AnnotationProcessingTaskFactory.java:228)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.project.taskfactory.AnnotationProcessingTaskFactory$StandardTaskAction.execute(AnnotationProcessingTaskFactory.java:221)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.project.taskfactory.AnnotationProcessingTaskFactory$StandardTaskAction.execute(AnnotationProcessingTaskFactory.java:210)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.AbstractTask$TaskActionWrapper.execute(AbstractTask.java:621)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.AbstractTask$TaskActionWrapper.execute(AbstractTask.java:604)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.executeAction(ExecuteActionsTaskExecuter.java:80)
# DEBUG:minerl.env.malmo.instance.7303d4:	at org.gradle.api.internal.tasks.execution.ExecuteActionsTaskExecuter.executeActions(ExecuteActionsTaskExecuter.java:61)
# DEBUG:minerl.env.malmo.instance.7303d4:	... 60 more
# DEBUG:minerl.env.malmo.instance.7303d4:
# DEBUG:minerl.env.malmo.instance.7303d4:
# DEBUG:minerl.env.malmo.instance.7303d4:BUILD FAILED
# DEBUG:minerl.env.malmo.instance.7303d4:
# DEBUG:minerl.env.malmo.instance.7303d4:Total time: 1 mins 0.713 secs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/minerl/env/comms.py in wrapper(*args, **kwargs)
#      38             try:
# ---> 39                 return func(*args, **kwargs)
#      40             except Pyro4.errors.PyroError as e:
#
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/minerl/env/core.py in _start_up(self)
#     509             self.done = False
# --> 510             return self._peek_obs()
#     511         except (socket.timeout, socket.error) as e:
#
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/minerl/env/core.py in _peek_obs(self)
#     552             obs = comms.recv_message(self.client_socket)
# --> 553             info = comms.recv_message(self.client_socket).decode('utf-8')
#     554
#
# AttributeError: 'NoneType' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-82337eb989c7> in <module>
#      16 # returned from AI gym. Typical dimensions at this point are close to 3x40x90
#      17 # which is the result of a clamped and down-scaled render buffer in get_screen()
# ---> 18 obs  = env.reset()
#      19
#      20 H,W,C = obs['pov'].shape
#
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/gym/wrappers/time_limit.py in reset(self, **kwargs)
#      23     def reset(self, **kwargs):
#      24         self._elapsed_steps = 0
# ---> 25         return self.env.reset(**kwargs)
#
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/minerl/env/core.py in reset(self)
#     485                     time.sleep(0.1)
#     486
# --> 487             return self._start_up()
#     488         finally:
#     489             # We don't force the same seed every episode, you gotta send it yourself queen.
#
# /opt/miniconda3/envs/minerl2/lib/python3.7/site-packages/minerl/env/comms.py in wrapper(*args, **kwargs)
#      47                     logger.debug("Pause before retry on " + str(e))
#      48                     # raise e
# ---> 49                     time.sleep(retry_timeout)
#      50                     logger.debug("Pause complete.")
#      51         raise retry_exc
#
# KeyboardInterrupt:
